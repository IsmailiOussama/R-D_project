# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/Project_R&D')

# %% [markdown]
# # d4rl utils

# %%
# !pip install gymnasium[mujoco]
# Out:
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Requirement already satisfied: mujoco>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (3.2.7)
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (2.36.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.11.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (2.8.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.21.0)

# %%
# !pip install torch numpy matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install just-d4rl
# Out:
# Requirement already satisfied: just-d4rl in /usr/local/lib/python3.11/dist-packages (0.2407.5)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from just-d4rl) (3.12.1)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.11/dist-packages (from just-d4rl) (4.67.1)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.11/dist-packages (from just-d4rl) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py>=3.11.0->just-d4rl) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->just-d4rl) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2->just-d4rl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2->just-d4rl) (3.0.2)

# %%
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: stable_baselines3 in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable_baselines3) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (3.0.2)

# %% [markdown]
# # MLE_Training_with_3_datasets
# ## Without returns

# %%
import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # without returns

# %%
from prettytable import PrettyTable
from just_d4rl import D4RLDataset, d4rl_offline_dataset, D4RLScoreNormalizer
import gymnasium as gym
import matplotlib.pyplot as plt
import torch
import numpy as np
import torch
import torch.nn as nn
from stable_baselines3.common import policies
from stable_baselines3.common.torch_layers import (
    BaseFeaturesExtractor,
    FlattenExtractor,
    MlpExtractor
)

class UnconditionalPolicy(policies.ActorCriticPolicy):
    """
    Policy that follows stable-baselines3's architecture for behavior cloning.
    This matches their implementation where features go through:
    1. Feature extraction (flattening for Box spaces)
    2. MLP extraction (separate networks for policy and value)
    3. Final action distribution
    """
    def __init__(
        self,
        observation_space,
        action_space,
        hidden_size=1024,
        depth=2,
        learning_rate=1e-3,
        dropout_p=0.1
    ):

        net_arch = dict(
            pi=[hidden_size] * depth,  # policy network architecture
            vf=[64]  # Small value network (we don't use it but need it)
        )

        # stable-baselines3's expected architecture
        super().__init__(
            observation_space=observation_space,
            action_space=action_space,
            lr_schedule=lambda _: learning_rate,
            net_arch=net_arch,
            activation_fn=nn.ReLU,
            features_extractor_class=FlattenExtractor,
            optimizer_class=torch.optim.Adam
        )

    def _build(self, lr_schedule):
        """
        Build the network following stable-baselines3's architecture.
        """

        self.features_extractor = self.features_extractor_class(self.observation_space)
        self.features_dim = self.features_extractor.features_dim

        # this just needed by stablebaselines, we do not normally need it. MLP extractor (handles splitting between policy and value)
        self.mlp_extractor = MlpExtractor(
            self.features_dim,
            net_arch=self.net_arch,
            activation_fn=self.activation_fn,
        )

        # Initialize the value network (required by architecture)
        self.value_net = nn.Linear(self.mlp_extractor.latent_dim_vf, 1)

        latent_dim_pi = self.mlp_extractor.latent_dim_pi
        self.action_net, self.log_std = self.action_dist.proba_distribution_net(
            latent_dim=latent_dim_pi,
            log_std_init=self.log_std_init
        )

def mle_loss(policy, obs, actions):
    _, log_prob, _ = policy.evaluate_actions(obs, actions)
    return -log_prob.mean()

def evaluate_on_env(model, device, env,
                    num_eval_ep=10, max_test_ep_len=1000,
                    state_mean=None, state_std=None, render=False,
                    state_normalization=True):

    eval_batch_size = 1
    results = {}
    total_reward = 0
    total_timesteps = 0

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    if state_mean is None:
        state_mean = torch.zeros((state_dim,)).to(device)
    else:
        state_mean = torch.from_numpy(state_mean).to(device)

    if state_std is None:
        state_std = torch.ones((state_dim,)).to(device)
    else:
        state_std = torch.from_numpy(state_std).to(device)

    model.eval()
    model.to(device)

    with torch.no_grad():
        return_per_ep_log = []
        all_rewards = []

        for ep in range(num_eval_ep):

            reset_result = env.reset()
            if isinstance(reset_result, tuple):  # Gymnasium style
                running_state, _ = reset_result
            else:  # Old Gym style
                running_state = reset_result

            running_reward = 0
            reward_per_ep = 0
            running_reward_log = []

            for t in range(max_test_ep_len):
                total_timesteps += 1

                state = torch.from_numpy(running_state).to(device, dtype=torch.float32)
                if state_normalization:
                    state = (state - state_mean) / state_std

                if len(state.shape) == 1:
                    state = state.unsqueeze(0)

                actions = model._predict(state, deterministic=True)


                step_result = env.step(actions.cpu().numpy().flatten())
                if len(step_result) == 5:  # Gymnasium style
                    running_state, running_reward, terminated, truncated, _ = step_result
                    done = terminated or truncated
                else:  # Old Gym style
                    running_state, running_reward, done, _ = step_result

                running_reward_log.append(running_reward)

                total_reward += running_reward
                reward_per_ep += running_reward

                if render:
                    env.render()
                if done:
                    print('sum of reward per episode: ', reward_per_ep)
                    return_per_ep_log.append(reward_per_ep)
                    break

    t = np.arange(len(running_reward_log))
    plt.plot(t, np.array(running_reward_log), 'b')
    plt.show()

    results['eval/avg_reward'] = total_reward / num_eval_ep
    results['eval/avg_ep_len'] = total_timesteps / num_eval_ep
    results['eval/std_returns'] = np.std(return_per_ep_log)
    results['eval/all_rewards'] = all_rewards

    return results

import gymnasium as gym

# List of dataset names
dataset_names = [
    ("halfcheetah-medium-replay-v2", 12000*0.001),
    ("hopper-medium-replay-v2", 3600*0.001),
    ("walker2d-medium-replay-v2", 5000*0.001)
]

# Initialize dictionary to store the results for each dataset
dataset_results = {}

for dataset_name, _ in dataset_names:  # Unpack the tuple to get the dataset name
    print(f"Training on dataset: {dataset_name}")

    eval_env = gym.make(dataset_name.split('-')[0].replace('halfcheetah', 'HalfCheetah').replace('hopper', 'Hopper').replace('walker2d', 'Walker2d') + '-v4')
    dataset = d4rl_offline_dataset(dataset_name)
    get_normalized_score = D4RLScoreNormalizer(dataset_name)

    states = dataset['observations']
    actions = dataset['actions']

    states_mean = states.mean(axis=0)
    states_std = states.std(axis=0) + 1e-6

    normalized_states = (states - states_mean) / states_std

    act_dim = actions.shape[1]
    obs_dim = states.shape[1]
    lr = 1e-4
    weight_decay = 1e-4
    epochs = 100
    device = 'cuda'

    actor = UnconditionalPolicy(
        observation_space=eval_env.observation_space,
        action_space=eval_env.action_space,
        hidden_size=1024,
        depth=2
    )

    optimizer = torch.optim.Adam(actor.parameters(),
                                        lr=lr,
                                        weight_decay=weight_decay,
                                        )

    from torch.utils.data import DataLoader, TensorDataset

    states_tensor = torch.tensor(normalized_states, dtype=torch.float32).to(device)
    actions_tensor = torch.tensor(actions, dtype=torch.float32).to(device).clamp(*[float(eval_env.action_space.low.min()) + 1e-6, float(eval_env.action_space.high.max()) - 1e-6])

    train_loader = DataLoader(TensorDataset(states_tensor, actions_tensor), batch_size=512, shuffle=True)

    actor.to(device)
    train_losses = []
    last_10_avg_scores = []  # To track last 10 average scores
    last_10_std_scores = []  # To track last 10 std scores

    for epoch in range(epochs):
        c = 0
        epoch_loss = 0.0
        actor.train()
        for x_batch, y_batch in train_loader:
            c += 1
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()

            loss = mle_loss(actor, x_batch, y_batch)
            loss.backward()

            torch.nn.utils.clip_grad_norm_(actor.parameters(), max_norm=1.0)

            optimizer.step()

            epoch_loss += loss.item()

        print('epoch loss: ', epoch_loss)
        train_losses.append(epoch_loss / len(train_loader))
        if epoch % 5 == 0:
            results = evaluate_on_env(actor, device, eval_env, 5, 1000,
                                    states_mean, states_std, render=False, state_normalization=True)

            eval_d4rl_score = get_normalized_score(results['eval/avg_reward']) * 100
            eval_d4rl_std = get_normalized_score(results['eval/std_returns']) * 100
            print(f'Epoch {epoch}, Average score: {eval_d4rl_score}')
            print(f'Std score: {eval_d4rl_std}')

            last_10_avg_scores.append(eval_d4rl_score)
            last_10_std_scores.append(eval_d4rl_std)

            # Keep only the last 10 scores
            if len(last_10_avg_scores) > 10:
                last_10_avg_scores.pop(0)
            if len(last_10_std_scores) > 10:
                last_10_std_scores.pop(0)

    # Save the trained model for this dataset
    model_save_path = f"actor_{dataset_name}.pth"
    torch.save(actor.state_dict(), model_save_path)
    print(f"Model saved to {model_save_path}")

    # Compute the mean of the last 10 scores for this dataset
    mean_avg_score = np.mean(last_10_avg_scores)
    mean_std_score = np.mean(last_10_std_scores)
    dataset_results[dataset_name] = {
        'avg_score': mean_avg_score,
        'std_score': mean_std_score
    }

# Display the results using PrettyTable
table = PrettyTable()
table.field_names = ["Dataset", "Avg Score", "Std Score"]

for dataset_name, results in dataset_results.items():
    table.add_row([dataset_name, f"{results['avg_score']:.2f}", f"{results['std_score']:.2f}"])

print("\nResults for all datasets:")
print(table)
# Out:
# Training on dataset: halfcheetah-medium-replay-v2
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/halfcheetah_medium_replay-v2.hdf5 to /root/.d4rl/datasets/halfcheetah_medium_replay-v2.hdf5
# load datafile: 100%|██████████| 11/11 [00:00<00:00, 25.39it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/halfcheetah_medium_replay-v2.hdf5
# epoch loss:  2370.04834651947
# sum of reward per episode:  -9.098302345121088
# sum of reward per episode:  -11.370453045415456
# sum of reward per episode:  -10.34901712237477
# sum of reward per episode:  -9.540476832682678
# sum of reward per episode:  -11.36491090468839
# Epoch 0, Average score: 2.1734227269010957
# Std score: 2.2642089427586396
# epoch loss:  2243.704138278961
# epoch loss:  2155.0556173324585
# epoch loss:  2071.913959503174
# epoch loss:  1992.1507606506348
# epoch loss:  1914.8608059883118
# sum of reward per episode:  -88.49425522640163
# sum of reward per episode:  -63.96137322986829
# sum of reward per episode:  -80.09457516827521
# sum of reward per episode:  -88.16687669335879
# sum of reward per episode:  -74.68083598108325
# Epoch 5, Average score: 1.6197863156181818
# Std score: 2.3305808969118833
# epoch loss:  1840.074610710144
# epoch loss:  1767.0264043807983
# epoch loss:  1696.5432510375977
# epoch loss:  1628.6231291294098
# epoch loss:  1564.0250804424286
# sum of reward per episode:  -104.06942979837602
# sum of reward per episode:  -94.29247203096041
# sum of reward per episode:  -104.03684478521134
# sum of reward per episode:  -62.58721046971108
# sum of reward per episode:  -111.94955078331537
# Epoch 10, Average score: 1.4884348596669401
# Std score: 2.3963278309092315
# epoch loss:  1500.7060034275055
# epoch loss:  1439.8671131134033
# epoch loss:  1382.2084214687347
# epoch loss:  1326.6879451274872
# epoch loss:  1274.0039498806
# sum of reward per episode:  -128.0483567829801
# sum of reward per episode:  -121.11529196555843
# sum of reward per episode:  -143.28582601229004
# sum of reward per episode:  -143.34101164924758
# sum of reward per episode:  -139.48843686877834
# Epoch 15, Average score: 1.1689172495508982
# Std score: 2.3287403270724583
# epoch loss:  1224.4749977588654
# epoch loss:  1177.915004491806
# epoch loss:  1133.6808588504791
# epoch loss:  1092.832721233368
# epoch loss:  1053.840987443924
# sum of reward per episode:  342.2010206428594
# sum of reward per episode:  323.9955835784916
# sum of reward per episode:  -127.92729245538948
# sum of reward per episode:  338.4708206930419
# sum of reward per episode:  343.94341048910286
# Epoch 20, Average score: 4.223182473442525
# Std score: 3.7562356809341857
# epoch loss:  1017.7261941432953
# epoch loss:  985.5270509719849
# epoch loss:  953.884477853775
# epoch loss:  927.3139429092407
# epoch loss:  901.2591322660446
# sum of reward per episode:  4295.682550995662
# sum of reward per episode:  -148.68432164542077
# sum of reward per episode:  -162.6380511750426
# sum of reward per episode:  -173.04245155448552
# sum of reward per episode:  4395.165732253486
# Epoch 25, Average score: 15.476826005077724
# Std score: 20.042622195220872
# epoch loss:  878.4880859851837
# epoch loss:  858.6974174976349
# epoch loss:  841.1775524616241
# epoch loss:  826.3658694028854
# epoch loss:  812.8967396020889
# sum of reward per episode:  4437.166982726425
# sum of reward per episode:  -92.13377350515712
# sum of reward per episode:  -124.56402381644708
# sum of reward per episode:  -106.28269245438186
# sum of reward per episode:  -99.42497558000512
# Epoch 30, Average score: 8.724250053700256
# Std score: 16.89317725913847
# epoch loss:  801.5726004838943
# epoch loss:  792.7464501857758
# epoch loss:  784.9456797838211
# epoch loss:  777.5579307079315
# epoch loss:  771.8032999038696
# sum of reward per episode:  4588.979988634286
# sum of reward per episode:  -104.09316084092305
# sum of reward per episode:  7.2103595166983645
# sum of reward per episode:  -123.66371115739673
# sum of reward per episode:  -124.39878530242888
# Epoch 35, Average score: 9.093593378267373
# Std score: 17.324777659135112
# epoch loss:  766.6682052612305
# epoch loss:  762.1506125926971
# epoch loss:  758.8710526227951
# epoch loss:  753.6206821203232
# epoch loss:  751.789540886879
# sum of reward per episode:  1963.57995283426
# sum of reward per episode:  3698.2477635272257
# sum of reward per episode:  4596.983744661362
# sum of reward per episode:  3551.188986608352
# sum of reward per episode:  4446.758086437038
# Epoch 40, Average score: 31.667128397401274
# Std score: 9.802111115313151
# epoch loss:  747.4905028343201
# epoch loss:  744.7182004451752
# epoch loss:  742.5213559865952
# epoch loss:  737.9930267333984
# epoch loss:  734.0274856090546
# sum of reward per episode:  10.285649119144672
# sum of reward per episode:  4576.194526114854
# sum of reward per episode:  4547.255741910472
# sum of reward per episode:  10.085271607828721
# sum of reward per episode:  -103.92003546410065
# Epoch 45, Average score: 16.819404630112544
# Std score: 20.37028140086922
# epoch loss:  732.1880853176117
# epoch loss:  728.4686037302017
# epoch loss:  725.5148285627365
# epoch loss:  723.6769634485245
# epoch loss:  719.5970344543457
# sum of reward per episode:  -107.50602981635161
# sum of reward per episode:  -109.59709766906153
# sum of reward per episode:  -100.98036241674696
# sum of reward per episode:  -123.92791397037212
# sum of reward per episode:  -101.72429953055884
# Epoch 50, Average score: 1.3808243358260819
# Std score: 2.3233958757001303
# epoch loss:  716.4911222457886
# epoch loss:  712.7905626296997
# epoch loss:  709.6423246860504
# epoch loss:  707.7144302129745
# epoch loss:  706.7082563638687
# sum of reward per episode:  2195.3382611502775
# sum of reward per episode:  4348.764982785713
# sum of reward per episode:  4287.653993303517
# sum of reward per episode:  4289.636757069322
# sum of reward per episode:  4410.034060281492
# Epoch 55, Average score: 33.7205333871281
# Std score: 9.156809007893745
# epoch loss:  703.1833322048187
# epoch loss:  699.4216977357864
# epoch loss:  697.8169575929642
# epoch loss:  695.288888335228
# epoch loss:  690.3132657408714
# sum of reward per episode:  4642.8914016958115
# sum of reward per episode:  4099.443905424593
# sum of reward per episode:  381.8762440698543
# sum of reward per episode:  4546.1142048608735
# sum of reward per episode:  2741.985368032121
# Epoch 60, Average score: 28.695850388493906
# Std score: 15.154540017884615
# epoch loss:  689.1269303560257
# epoch loss:  687.1046798229218
# epoch loss:  683.9911911487579
# epoch loss:  682.0358462333679
# epoch loss:  678.899449467659
# sum of reward per episode:  4386.206669520712
# sum of reward per episode:  4556.246419484666
# sum of reward per episode:  4692.941297488978
# sum of reward per episode:  4571.235183435711
# sum of reward per episode:  3910.3883247670096
# Epoch 65, Average score: 37.88574091235995
# Std score: 4.46765737559683
# epoch loss:  676.2248747348785
# epoch loss:  673.5310813784599
# epoch loss:  670.6716510057449
# epoch loss:  668.0277967453003
# epoch loss:  665.6236124038696
# sum of reward per episode:  4598.592949938236
# sum of reward per episode:  3611.327134068393
# sum of reward per episode:  4536.071573771933
# sum of reward per episode:  4309.8735093481555
# sum of reward per episode:  4243.693878140788
# Epoch 70, Average score: 36.56887088974614
# Std score: 5.080221999043241
# epoch loss:  663.7315222024918
# epoch loss:  662.623121380806
# epoch loss:  660.0504393577576
# epoch loss:  657.402419090271
# epoch loss:  654.4180335998535
# sum of reward per episode:  1929.1802160040775
# sum of reward per episode:  4466.889475031502
# sum of reward per episode:  3476.957391633976
# sum of reward per episode:  4619.46428140102
# sum of reward per episode:  2529.468564355516
# Epoch 75, Average score: 29.677952711224346
# Std score: 10.74461661233816
# epoch loss:  652.254515171051
# epoch loss:  650.3083980083466
# epoch loss:  647.4339973926544
# epoch loss:  645.7295542955399
# epoch loss:  644.1801198720932
# sum of reward per episode:  4428.939330176132
# sum of reward per episode:  359.8368217781384
# sum of reward per episode:  4215.956211362781
# sum of reward per episode:  343.9227110809905
# sum of reward per episode:  4248.422843901109
# Epoch 80, Average score: 24.160703184507927
# Std score: 17.83810130989771
# epoch loss:  641.485710144043
# epoch loss:  640.2135071754456
# epoch loss:  637.0124932527542
# epoch loss:  635.269647359848
# epoch loss:  632.8433438539505
# sum of reward per episode:  4506.8861882344145
# sum of reward per episode:  4479.101830249158
# sum of reward per episode:  4496.983124730461
# sum of reward per episode:  4409.830595409569
# sum of reward per episode:  4669.525109026707
# Epoch 85, Average score: 38.6031030295537
# Std score: 2.945741933257232
# epoch loss:  631.4007232189178
# epoch loss:  628.0824815034866
# epoch loss:  625.9745491743088
# epoch loss:  623.8748641610146
# epoch loss:  623.5012929439545
# sum of reward per episode:  4595.4068832200755
# sum of reward per episode:  4656.210610932193
# sum of reward per episode:  4744.7481700923745
# sum of reward per episode:  4520.766034095807
# sum of reward per episode:  4697.292512382196
# Epoch 90, Average score: 39.65358706291469
# Std score: 2.887698534578757
# epoch loss:  620.8320399522781
# epoch loss:  618.0331417322159
# epoch loss:  616.294195652008
# epoch loss:  613.2288547158241
# epoch loss:  612.1427092552185
# sum of reward per episode:  4297.922146334617
# sum of reward per episode:  4337.84190686675
# sum of reward per episode:  4138.272156902001
# sum of reward per episode:  4375.797792483734
# sum of reward per episode:  4426.5976976228385
# Epoch 95, Average score: 37.014893707444536
# Std score: 3.047547914834793
# epoch loss:  610.0056470632553
# epoch loss:  607.3200279474258
# epoch loss:  606.4966889619827
# epoch loss:  604.4863506555557
# Model saved to actor_halfcheetah-medium-replay-v2.pth
# Training on dataset: hopper-medium-replay-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/hopper_medium_replay-v2.hdf5 to /root/.d4rl/datasets/hopper_medium_replay-v2.hdf5
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# load datafile: 100%|██████████| 11/11 [00:00<00:00, 19.34it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/hopper_medium_replay-v2.hdf5
# epoch loss:  2353.3650035858154
# sum of reward per episode:  1009.3124337450737
# sum of reward per episode:  1006.9996207947363
# sum of reward per episode:  1004.4997409251608
# sum of reward per episode:  1009.96064818011
# sum of reward per episode:  1010.873237596751
# Epoch 0, Average score: 31.60481147301979
# Std score: 0.6936675650965579
# epoch loss:  2174.830661058426
# epoch loss:  2025.2056856155396
# epoch loss:  1888.4975547790527
# epoch loss:  1762.6312637329102
# epoch loss:  1648.5882396697998
# sum of reward per episode:  1383.5138369803228
# sum of reward per episode:  1131.405104767602
# sum of reward per episode:  1403.8626442722114
# sum of reward per episode:  1266.4467430213165
# sum of reward per episode:  1239.8119962129465
# Epoch 5, Average score: 40.106049204854955
# Std score: 3.6896706968775757
# epoch loss:  1548.0508046150208
# epoch loss:  1457.4631552696228
# epoch loss:  1378.5453044176102
# epoch loss:  1310.396567940712
# epoch loss:  1253.2851068973541
# sum of reward per episode:  279.13032152902946
# sum of reward per episode:  352.599298519339
# sum of reward per episode:  228.19914741534635
# sum of reward per episode:  377.0440047004383
# sum of reward per episode:  586.6415504151252
# Epoch 10, Average score: 11.829362921954072
# Std score: 4.398849056327184
# epoch loss:  1207.0605890750885
# epoch loss:  1168.3412116765976
# epoch loss:  1139.335395693779
# epoch loss:  1116.1089078187943
# epoch loss:  1099.559334039688
# sum of reward per episode:  228.90431512578542
# sum of reward per episode:  344.38622472337653
# sum of reward per episode:  544.3670877828006
# sum of reward per episode:  173.75837093679618
# sum of reward per episode:  188.38763912776753
# Epoch 15, Average score: 9.716577261272596
# Std score: 4.859348705287772
# epoch loss:  1086.5328093767166
# epoch loss:  1077.9336136579514
# epoch loss:  1070.9677520990372
# epoch loss:  1064.6112382411957
# epoch loss:  1060.0012687444687
# sum of reward per episode:  311.18512207613486
# sum of reward per episode:  450.0694194515986
# sum of reward per episode:  426.361216137168
# sum of reward per episode:  758.4523205587814
# sum of reward per episode:  504.1047480635928
# Epoch 20, Average score: 15.679690676205595
# Std score: 5.177900461312254
# epoch loss:  1055.3238717317581
# epoch loss:  1049.9870847463608
# epoch loss:  1045.7696367502213
# epoch loss:  1041.4703059196472
# epoch loss:  1036.352202653885
# sum of reward per episode:  360.8954245146449
# sum of reward per episode:  427.86602359719296
# sum of reward per episode:  223.42768293391723
# sum of reward per episode:  342.12026045615
# sum of reward per episode:  125.51373062132069
# Epoch 25, Average score: 9.716696996985135
# Std score: 3.933874222944959
# epoch loss:  1032.8776035308838
# epoch loss:  1029.8948546648026
# epoch loss:  1025.735622882843
# epoch loss:  1022.4611701965332
# epoch loss:  1018.278755903244
# sum of reward per episode:  446.921442247788
# sum of reward per episode:  558.5303341441079
# sum of reward per episode:  374.10091539097687
# sum of reward per episode:  374.0326102923772
# sum of reward per episode:  404.8561794085281
# Epoch 30, Average score: 13.886943012524513
# Std score: 2.737469956603599
# epoch loss:  1015.0478152036667
# epoch loss:  1011.7242813110352
# epoch loss:  1008.1180766820908
# epoch loss:  1006.0816262960434
# epoch loss:  1003.1373397111893
# sum of reward per episode:  528.2054380195144
# sum of reward per episode:  515.0067640463626
# sum of reward per episode:  548.4115243842429
# sum of reward per episode:  575.7213124153901
# sum of reward per episode:  521.9618482472869
# Epoch 35, Average score: 17.14921747367845
# Std score: 1.297887046689798
# epoch loss:  999.9254870414734
# epoch loss:  997.2307275533676
# epoch loss:  994.8707510232925
# epoch loss:  991.8137226104736
# epoch loss:  990.2765746116638
# sum of reward per episode:  445.4939819479759
# sum of reward per episode:  241.10343669005675
# sum of reward per episode:  589.3413649231118
# sum of reward per episode:  413.98526570972456
# sum of reward per episode:  335.4577682873441
# Epoch 40, Average score: 13.069264672908936
# Std score: 4.190291376666756
# epoch loss:  986.8923252820969
# epoch loss:  985.4649803638458
# epoch loss:  982.174989938736
# epoch loss:  980.0074065923691
# epoch loss:  977.9936760663986
# sum of reward per episode:  1001.0519977147126
# sum of reward per episode:  1005.733157412949
# sum of reward per episode:  1170.6431784160197
# sum of reward per episode:  999.6919450262251
# sum of reward per episode:  1001.5239580983454
# Epoch 45, Average score: 32.44669509143533
# Std score: 2.6965045024502334
# epoch loss:  976.5817725658417
# epoch loss:  974.868924498558
# epoch loss:  972.1570807695389
# epoch loss:  970.2913608551025
# epoch loss:  967.9080798625946
# sum of reward per episode:  397.91915057292067
# sum of reward per episode:  385.420327891803
# sum of reward per episode:  385.42507646031515
# sum of reward per episode:  391.819853567659
# sum of reward per episode:  446.718668927924
# Epoch 50, Average score: 12.958167186398539
# Std score: 1.3326784779602285
# epoch loss:  966.2843906879425
# epoch loss:  964.3630023002625
# epoch loss:  963.0619622468948
# epoch loss:  959.7175521850586
# epoch loss:  959.0126394033432
# sum of reward per episode:  337.6513120377429
# sum of reward per episode:  308.9891959505221
# sum of reward per episode:  288.34732864287685
# sum of reward per episode:  409.35280624147987
# sum of reward per episode:  420.07337649774894
# Epoch 55, Average score: 11.46556517735975
# Std score: 2.2503159574499105
# epoch loss:  957.9107136130333
# epoch loss:  957.3384610414505
# epoch loss:  954.5412125587463
# epoch loss:  952.9434673190117
# epoch loss:  952.6652317047119
# sum of reward per episode:  1759.6242878495311
# sum of reward per episode:  420.75810211452784
# sum of reward per episode:  1613.9381561757507
# sum of reward per episode:  1000.7742603127924
# sum of reward per episode:  1003.8512731828101
# Epoch 60, Average score: 36.258574409735935
# Std score: 15.434113063537685
# epoch loss:  949.695898771286
# epoch loss:  947.8361055254936
# epoch loss:  946.4684745073318
# epoch loss:  946.4337623119354
# epoch loss:  944.0410920381546
# sum of reward per episode:  452.1104891295825
# sum of reward per episode:  436.1830457219449
# sum of reward per episode:  695.9500128089805
# sum of reward per episode:  397.44224705170546
# sum of reward per episode:  441.2204796857996
# Epoch 65, Average score: 15.512132242506835
# Std score: 3.9192258579167762
# epoch loss:  943.1052769422531
# epoch loss:  941.5094864368439
# epoch loss:  940.0048356056213
# epoch loss:  938.207634806633
# epoch loss:  936.9624149799347
# sum of reward per episode:  280.62761621700463
# sum of reward per episode:  307.6095308912073
# sum of reward per episode:  381.33426600600745
# sum of reward per episode:  373.9217893955492
# sum of reward per episode:  266.6373988781178
# Epoch 70, Average score: 10.517462609501846
# Std score: 2.077119885087104
# epoch loss:  935.7402513027191
# epoch loss:  933.7302443385124
# epoch loss:  934.6272569894791
# epoch loss:  931.8590292930603
# epoch loss:  930.2578796744347
# sum of reward per episode:  970.3646045663603
# sum of reward per episode:  483.14738063833124
# sum of reward per episode:  976.3947611958314
# sum of reward per episode:  919.2606745137153
# sum of reward per episode:  479.74896233055455
# Epoch 75, Average score: 24.152346544624066
# Std score: 7.782305607667967
# epoch loss:  930.0743730068207
# epoch loss:  930.0485733151436
# epoch loss:  927.8000690340996
# epoch loss:  926.4214633107185
# epoch loss:  926.3799638152122
# sum of reward per episode:  412.2418492287235
# sum of reward per episode:  664.6590131574887
# sum of reward per episode:  949.4821988387649
# sum of reward per episode:  734.2443518008806
# sum of reward per episode:  667.8878448184897
# Epoch 80, Average score: 21.691801269379667
# Std score: 5.8998391090029285
# epoch loss:  924.479907810688
# epoch loss:  923.9985765814781
# epoch loss:  921.9484290480614
# epoch loss:  921.2320098280907
# epoch loss:  920.0835543870926
# sum of reward per episode:  448.15141122756705
# sum of reward per episode:  1040.2293126483512
# sum of reward per episode:  251.05962636435962
# sum of reward per episode:  207.77537689478882
# sum of reward per episode:  227.62731125163978
# Epoch 85, Average score: 13.987733871450775
# Std score: 10.290051317470834
# epoch loss:  918.0189313292503
# epoch loss:  916.9125421643257
# epoch loss:  917.9520791172981
# epoch loss:  914.8154119253159
# epoch loss:  913.8363054394722
# sum of reward per episode:  429.0731775443532
# sum of reward per episode:  378.66815882156527
# sum of reward per episode:  433.56448344460773
# sum of reward per episode:  437.85541833303637
# sum of reward per episode:  387.5617525431774
# Epoch 90, Average score: 13.323314478869694
# Std score: 1.3909414805147493
# epoch loss:  913.5690830349922
# epoch loss:  912.2987615466118
# epoch loss:  912.3346543908119
# epoch loss:  910.6133365631104
# epoch loss:  910.6044746041298
# sum of reward per episode:  1000.995401214954
# sum of reward per episode:  480.5048890979718
# sum of reward per episode:  399.177082826512
# sum of reward per episode:  404.57515955165104
# sum of reward per episode:  1001.7816040768266
# Epoch 95, Average score: 20.822371385403365
# Std score: 9.297723558709537
# epoch loss:  908.3996014595032
# epoch loss:  908.2650616765022
# epoch loss:  906.8250534534454
# epoch loss:  906.736247420311
# Model saved to actor_hopper-medium-replay-v2.pth
# Training on dataset: walker2d-medium-replay-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/walker2d_medium_replay-v2.hdf5 to /root/.d4rl/datasets/walker2d_medium_replay-v2.hdf5
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Walker2d-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# load datafile: 100%|██████████| 11/11 [00:00<00:00, 16.78it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/walker2d_medium_replay-v2.hdf5
# epoch loss:  3490.6178302764893
# sum of reward per episode:  244.77742653320445
# sum of reward per episode:  246.83331071003767
# sum of reward per episode:  247.88341892985196
# sum of reward per episode:  244.4598952149015
# sum of reward per episode:  244.77924649324956
# Epoch 0, Average score: 5.317689984790118
# Std score: -0.005812488056002289
# epoch loss:  3270.0266218185425
# epoch loss:  3087.480950832367
# epoch loss:  2914.22247505188
# epoch loss:  2749.5780215263367
# epoch loss:  2592.112736225128
# sum of reward per episode:  242.28215341958847
# sum of reward per episode:  613.2487480013838
# sum of reward per episode:  657.3995037297861
# sum of reward per episode:  587.7670103504083
# sum of reward per episode:  248.1572999154801
# Epoch 5, Average score: 10.197679944808577
# Std score: 3.98797123486324
# epoch loss:  2442.884798526764
# epoch loss:  2301.722267150879
# epoch loss:  2168.5568935871124
# epoch loss:  2045.1841564178467
# epoch loss:  1931.941018819809
# sum of reward per episode:  157.03399621219958
# sum of reward per episode:  39.2027077100196
# sum of reward per episode:  283.17391822747794
# sum of reward per episode:  273.08749609659066
# sum of reward per episode:  559.1833705521889
# Epoch 10, Average score: 5.6790671824232435
# Std score: 3.731769662014777
# epoch loss:  1827.7318031787872
# epoch loss:  1732.1779232025146
# epoch loss:  1648.3510990142822
# epoch loss:  1572.5059220790863
# epoch loss:  1505.551257133484
# sum of reward per episode:  473.6738228423117
# sum of reward per episode:  438.74994340515946
# sum of reward per episode:  221.2121455755575
# sum of reward per episode:  264.50938700578524
# sum of reward per episode:  602.858493722737
# Epoch 15, Average score: 8.682211188841183
# Std score: 3.0204506809388363
# epoch loss:  1447.2034752368927
# epoch loss:  1396.971450805664
# epoch loss:  1356.2877418994904
# epoch loss:  1323.3410377502441
# epoch loss:  1296.8528212308884
# sum of reward per episode:  223.5036379494538
# sum of reward per episode:  3818.1586215577554
# sum of reward per episode:  693.6347485439927
# sum of reward per episode:  225.26437314899374
# sum of reward per episode:  872.2796743378907
# Epoch 20, Average score: 25.37622942567037
# Std score: 29.37863940069722
# epoch loss:  1275.5932710170746
# epoch loss:  1259.642382144928
# epoch loss:  1245.899875998497
# epoch loss:  1234.4240190982819
# epoch loss:  1226.4212690591812
# sum of reward per episode:  471.00602260508253
# sum of reward per episode:  536.3056069683614
# sum of reward per episode:  250.5296582736075
# sum of reward per episode:  554.8345663118214
# sum of reward per episode:  405.99848622963225
# Epoch 25, Average score: 9.630528104674529
# Std score: 2.358865797465587
# epoch loss:  1217.6698929071426
# epoch loss:  1210.6767762899399
# epoch loss:  1203.9754256010056
# epoch loss:  1196.2992470264435
# epoch loss:  1188.741244673729
# sum of reward per episode:  253.10807327377483
# sum of reward per episode:  259.00721295613295
# sum of reward per episode:  245.66203361317125
# sum of reward per episode:  421.9847017444181
# sum of reward per episode:  245.08821239164536
# Epoch 30, Average score: 6.172105108155148
# Std score: 1.461012232639544
# epoch loss:  1184.5549764633179
# epoch loss:  1177.0953396558762
# epoch loss:  1169.8135418891907
# epoch loss:  1162.783220410347
# epoch loss:  1158.406734585762
# sum of reward per episode:  225.8330827824208
# sum of reward per episode:  662.1437571494282
# sum of reward per episode:  648.0181037450535
# sum of reward per episode:  734.5627227172611
# sum of reward per episode:  301.5649207924788
# Epoch 35, Average score: 11.170382506848325
# Std score: 4.499664288655513
# epoch loss:  1151.9112790822983
# epoch loss:  1146.334859251976
# epoch loss:  1141.1678873300552
# epoch loss:  1136.0461542606354
# epoch loss:  1129.8680480718613
# sum of reward per episode:  -16.953798112967696
# sum of reward per episode:  -21.39933034930168
# sum of reward per episode:  -21.198441887211334
# sum of reward per episode:  -24.62883148263588
# sum of reward per episode:  -20.38394178086041
# Epoch 40, Average score: -0.49103664283235177
# Std score: 0.017944418194519952
# epoch loss:  1125.0411077737808
# epoch loss:  1119.7207330465317
# epoch loss:  1113.8567107915878
# epoch loss:  1109.9745032787323
# epoch loss:  1103.761783003807
# sum of reward per episode:  247.27313748955572
# sum of reward per episode:  409.8880226892106
# sum of reward per episode:  573.7786303877681
# sum of reward per episode:  440.7024529246998
# sum of reward per episode:  468.5581134759987
# Epoch 45, Average score: 9.288643515001137
# Std score: 2.270830332736646
# epoch loss:  1101.2173709869385
# epoch loss:  1095.4540585279465
# epoch loss:  1090.8341341018677
# epoch loss:  1084.8468353748322
# epoch loss:  1081.6058541536331
# sum of reward per episode:  255.0015048030291
# sum of reward per episode:  2063.5981539239574
# sum of reward per episode:  233.4047647291076
# sum of reward per episode:  365.88513440085455
# sum of reward per episode:  562.0581786199349
# Epoch 50, Average score: 15.125469468524624
# Std score: 15.074391318823977
# epoch loss:  1076.2715902328491
# epoch loss:  1072.0161848068237
# epoch loss:  1068.4735633134842
# epoch loss:  1064.8886437416077
# epoch loss:  1061.0172698497772
# sum of reward per episode:  237.77246568442754
# sum of reward per episode:  1694.6447266777254
# sum of reward per episode:  742.3957394370593
# sum of reward per episode:  261.37527484177684
# sum of reward per episode:  238.429430107112
# Epoch 55, Average score: 13.795249549646218
# Std score: 12.24471486859826
# epoch loss:  1055.2795330286026
# epoch loss:  1052.3069050312042
# epoch loss:  1048.00621175766
# epoch loss:  1043.9672013521194
# epoch loss:  1041.1710749864578
# sum of reward per episode:  263.62052443562743
# sum of reward per episode:  261.2982936217689
# sum of reward per episode:  640.0244499295669
# sum of reward per episode:  263.36358341565693
# sum of reward per episode:  939.7439040678629
# Epoch 60, Average score: 10.281310595261587
# Std score: 5.956706370345309
# epoch loss:  1037.0022984743118
# epoch loss:  1033.455403804779
# epoch loss:  1028.348777294159
# epoch loss:  1025.220565199852
# epoch loss:  1022.5519564151764
# sum of reward per episode:  556.7845838706997
# sum of reward per episode:  229.24909326362754
# sum of reward per episode:  613.6227806605348
# sum of reward per episode:  476.12805556609777
# sum of reward per episode:  400.4695410543492
# Epoch 65, Average score: 9.881383433349338
# Std score: 2.8854998364489477
# epoch loss:  1017.0381566286087
# epoch loss:  1015.1554281711578
# epoch loss:  1011.885279417038
# epoch loss:  1008.4141061306
# epoch loss:  1005.4617705345154
# sum of reward per episode:  1300.3622519727683
# sum of reward per episode:  939.2578621131732
# sum of reward per episode:  1699.039990823792
# sum of reward per episode:  939.5886650987483
# sum of reward per episode:  190.9175925967855
# Epoch 70, Average score: 22.04915722091577
# Std score: 10.8119507341749
# epoch loss:  1001.7206341028214
# epoch loss:  997.5575978755951
# epoch loss:  994.9563120603561
# epoch loss:  991.5678017139435
# epoch loss:  987.3311083316803
# sum of reward per episode:  237.79470079980072
# sum of reward per episode:  211.2264752741527
# sum of reward per episode:  228.95920624393688
# sum of reward per episode:  258.73003148478955
# sum of reward per episode:  233.0672150016705
# Epoch 75, Average score: 5.060840085593965
# Std score: 0.29786027993810293
# epoch loss:  986.2484775781631
# epoch loss:  982.9834685325623
# epoch loss:  978.5168213844299
# epoch loss:  976.83857691288
# epoch loss:  974.1057823896408
# sum of reward per episode:  239.99252581511075
# sum of reward per episode:  239.08375641336625
# sum of reward per episode:  243.24188080921556
# sum of reward per episode:  233.96497544753905
# sum of reward per episode:  245.77997975138408
# Epoch 80, Average score: 5.201497037436205
# Std score: 0.051826350892889415
# epoch loss:  970.653093457222
# epoch loss:  967.9082673788071
# epoch loss:  964.2375993728638
# epoch loss:  962.2280557155609
# epoch loss:  958.3210971355438
# sum of reward per episode:  619.6596376933786
# sum of reward per episode:  889.3398371708973
# sum of reward per episode:  244.84319465901783
# sum of reward per episode:  231.90326105095173
# sum of reward per episode:  282.3458347293301
# Epoch 85, Average score: 9.845823101859864
# Std score: 5.640743686968807
# epoch loss:  956.4685552120209
# epoch loss:  954.1958186626434
# epoch loss:  949.6565763950348
# epoch loss:  947.5593329668045
# epoch loss:  945.5179917812347
# sum of reward per episode:  202.84177677057247
# sum of reward per episode:  204.11226518997043
# sum of reward per episode:  186.60638775676497
# sum of reward per episode:  213.6080870220455
# sum of reward per episode:  202.11792478574026
# Epoch 90, Average score: 4.361634293852671
# Std score: 0.15361433407550554
# epoch loss:  944.0803693532944
# epoch loss:  939.0085940361023
# epoch loss:  936.745436668396
# epoch loss:  934.7713204622269
# epoch loss:  933.2691462039948
# sum of reward per episode:  232.98541848738998
# sum of reward per episode:  245.16675662563173
# sum of reward per episode:  245.63672757402458
# sum of reward per episode:  241.51420032734364
# sum of reward per episode:  407.5838441015482
# Epoch 95, Average score: 5.945718651997607
# Std score: 1.4165428314077084
# epoch loss:  929.4707674980164
# epoch loss:  927.0100647211075
# epoch loss:  926.3322365283966
# epoch loss:  921.8358249664307
# Model saved to actor_walker2d-medium-replay-v2.pth
#
# Results for all datasets:
# +------------------------------+-----------+-----------+
# |           Dataset            | Avg Score | Std Score |
# +------------------------------+-----------+-----------+
# | halfcheetah-medium-replay-v2 |   30.74   |    7.36   |
# |   hopper-medium-replay-v2    |   18.07   |    5.97   |
# |  walker2d-medium-replay-v2   |   10.15   |    5.45   |
# +------------------------------+-----------+-----------+
