# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/Project_R&D')

# %% [markdown]
# # d4rl utils

# %%
# !pip install gymnasium[mujoco]
# Out:
# Collecting gymnasium[mujoco]
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium[mujoco])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting mujoco>=2.1.5 (from gymnasium[mujoco])
#   Downloading mujoco-3.2.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[mujoco]) (2.36.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.11.0)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.21.0)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading mujoco-3.2.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 59.1 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 47.2 MB/s eta 0:00:00
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 17.6 MB/s eta 0:00:00
# Installing collected packages: glfw, farama-notifications, gymnasium, mujoco
# Successfully installed farama-notifications-0.0.4 glfw-2.8.0 gymnasium-1.0.0 mujoco-3.2.7

# %%
# !pip install torch numpy matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install just-d4rl
# Out:
# Collecting just-d4rl
#   Downloading just_d4rl-0.2407.5-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from just-d4rl) (3.12.1)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.11/dist-packages (from just-d4rl) (4.67.1)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.11/dist-packages (from just-d4rl) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py>=3.11.0->just-d4rl) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2->just-d4rl) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->just-d4rl) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2->just-d4rl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2->just-d4rl) (3.0.2)
# Downloading just_d4rl-0.2407.5-py3-none-any.whl (8.2 kB)
# Installing collected packages: just-d4rl
# Successfully installed just-d4rl-0.2407.5

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.4.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable_baselines3) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.4.1-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: stable_baselines3
# Successfully installed stable_baselines3-2.4.1

# %% [markdown]
# # MLE_Training_with_3_datasets
# ## With returns

# %%
import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from just_d4rl import D4RLDataset, d4rl_offline_dataset, D4RLScoreNormalizer
import gymnasium as gym
import matplotlib.pyplot as plt
import torch
import numpy as np
import torch.nn as nn
from stable_baselines3.common import policies
from stable_baselines3.common.torch_layers import FlattenExtractor, MlpExtractor
import collections
from torch.utils.data import DataLoader, TensorDataset
from prettytable import PrettyTable

# Define the MLE model (UnconditionalPolicy)
class UnconditionalPolicy(policies.ActorCriticPolicy):
    def __init__(
        self,
        observation_space,
        action_space,
        hidden_size=1024,
        depth=2,
        learning_rate=1e-3,
        dropout_p=0.1
    ):
        net_arch = dict(
            pi=[hidden_size] * depth,  # policy network architecture
            vf=[64]  # Small value network (we don't use it but need it)
        )

        super().__init__(
            observation_space=observation_space,
            action_space=action_space,
            lr_schedule=lambda _: learning_rate,
            net_arch=net_arch,
            activation_fn=nn.ReLU,
            features_extractor_class=FlattenExtractor,
            optimizer_class=torch.optim.Adam
        )

    def _build(self, lr_schedule):
        self.features_extractor = self.features_extractor_class(self.observation_space)
        self.features_dim = self.features_extractor.features_dim

        self.mlp_extractor = MlpExtractor(
            self.features_dim,
            net_arch=self.net_arch,
            activation_fn=self.activation_fn,
        )

        self.value_net = nn.Linear(self.mlp_extractor.latent_dim_vf, 1)

        latent_dim_pi = self.mlp_extractor.latent_dim_pi
        self.action_net, self.log_std = self.action_dist.proba_distribution_net(
            latent_dim=latent_dim_pi,
            log_std_init=self.log_std_init
        )

def mle_loss(policy, obs, actions):
    _, log_prob, _ = policy.evaluate_actions(obs, actions)
    return -log_prob.mean()

def evaluate_on_env(model, device, env, desired_return_target,
                    num_eval_ep=10, max_test_ep_len=1000,
                    state_mean=None, state_std=None, render=False,
                    state_normalization=True):

    eval_batch_size = 1
    results = {}
    total_reward = 0
    total_timesteps = 0

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    if state_mean is None:
        state_mean = torch.zeros((state_dim,)).to(device)
    else:
        state_mean = torch.from_numpy(state_mean).to(device)

    if state_std is None:
        state_std = torch.ones((state_dim,)).to(device)
    else:
        state_std = torch.from_numpy(state_std).to(device)

    model.eval()
    model.to(device)

    with torch.no_grad():
        return_per_ep_log = []
        all_rewards = []


        for ep in range(num_eval_ep):

            reset_result = env.reset()
            if isinstance(reset_result, tuple):  # Gymnasium style
                running_state, _ = reset_result
            else:  # Old Gym style
                running_state = reset_result

            running_reward = 0
            reward_per_ep = 0
            running_reward_log = []
            desired_return = desired_return_target
            for t in range(max_test_ep_len):
                total_timesteps += 1
                desired_return -= running_reward*0.001

                state = torch.from_numpy(running_state).to(device, dtype=torch.float32)
                if state_normalization:
                    state = (state - state_mean) / state_std

                if len(state.shape) == 1:
                    state = state.unsqueeze(0)


                state = torch.cat([state, torch.from_numpy(np.array(desired_return)).to(device, dtype=torch.float32).reshape((1,1))], dim=1)

                actions = model._predict(state, deterministic=True)

                step_result = env.step(actions.cpu().numpy().flatten())
                if len(step_result) == 5:  # Gymnasium style
                    running_state, running_reward, terminated, truncated, _ = step_result
                    done = terminated or truncated
                else:  # Old Gym style
                    running_state, running_reward, done, _ = step_result

                running_reward_log.append(running_reward)

                total_reward += running_reward
                reward_per_ep += running_reward

                if render:
                    env.render()
                if done:
                    print('sum of reward per episode: ', reward_per_ep)
                    return_per_ep_log.append(reward_per_ep)
                    break

    t = np.arange(len(running_reward_log))
    plt.plot(t, np.array(running_reward_log), 'b')
    plt.show()

    results['eval/avg_reward'] = total_reward / num_eval_ep
    results['eval/avg_ep_len'] = total_timesteps / num_eval_ep
    results['eval/std_returns'] = np.std(return_per_ep_log)
    results['eval/all_rewards'] = all_rewards

    return results

def flatten_traj(paths):
    states_list = []
    actions_list = []

    for p in paths:
        states_list.append(p['observations'])
        actions_list.append(p['actions'])

    states = np.concatenate(states_list)
    actions = np.concatenate(actions_list)

    return(states, actions)

def save_model(model, dataset_name):
    model_filename = f"trained_mle_model_{dataset_name}.pth"
    torch.save(model.state_dict(), model_filename)
    print(f"Model saved to {model_filename}")

# List of datasets
dataset_list = [
    ("halfcheetah-medium-replay-v2", 12000*0.001),
    ("hopper-medium-replay-v2", 3600*0.001),
    ("walker2d-medium-replay-v2", 5000*0.001)
]

results_table = PrettyTable()
results_table.field_names = ["Dataset", "Mean Last 10 Average Scores", "Mean Last 10 Std Scores"]

lr = 5e-4
weight_decay = 1e-4
epochs = 100
device = 'cuda'

for dataset_name, desired_return in dataset_list:
    print(f"Training on dataset: {dataset_name}")

    eval_env = gym.make(dataset_name.split('-')[0].replace('halfcheetah', 'HalfCheetah').replace('hopper', 'Hopper').replace('walker2d', 'Walker2d') + '-v4')

    dataset = d4rl_offline_dataset(dataset_name)
    get_normalized_score = D4RLScoreNormalizer(dataset_name)

    states = dataset['observations']
    actions = dataset['actions']

    act_dim = actions.shape[1]
    obs_dim = states.shape[1]

    N = dataset['rewards'].shape[0]
    data_ = collections.defaultdict(list)

    use_timeouts = False
    if 'timeouts' in dataset:
        use_timeouts = True

    episode_step = 0
    paths = []
    for i in range(N):
        done_bool = bool(dataset['terminals'][i])
        if use_timeouts:
            final_timestep = dataset['timeouts'][i]
        else:
            final_timestep = (episode_step == 1000-1)
        for k in ['observations', 'next_observations', 'actions', 'rewards', 'terminals']:
            data_[k].append(dataset[k][i])
        if done_bool or final_timestep:
            episode_step = 0
            episode_data = {}
            for k in data_:
                episode_data[k] = np.array(data_[k])
            paths.append(episode_data)
            data_ = collections.defaultdict(list)
        episode_step += 1

    gamma = 1.0
    returns_input = []

    for path in paths:
        return_sum = 0
        returns_per_traj = np.zeros_like(path['rewards'])
        for t in reversed(range(len(path['rewards']))):
            return_sum = gamma * return_sum + path['rewards'][t]*0.001
            returns_per_traj[t] = return_sum
        returns_input.append(returns_per_traj)
    returns_input = np.concatenate(returns_input)

    states_input, actions_input = flatten_traj(paths)

    states_mean = states_input.mean(axis=0)
    states_std = states_input.std(axis=0) + 1e-6

    normalized_states = (states_input - states_mean) / states_std

    states_tensor = torch.tensor(normalized_states, dtype=torch.float32).to(device)
    actions_tensor = torch.tensor(actions_input, dtype=torch.float32).to(device)

    augmented_obs_space = gym.spaces.Box(
        low=np.concatenate([eval_env.observation_space.low, [-np.inf]]),
        high=np.concatenate([eval_env.observation_space.high, [np.inf]]),
        shape=(eval_env.observation_space.shape[0] + 1,),
        dtype=np.float32
    )

    actor = UnconditionalPolicy(
        observation_space=augmented_obs_space,
        action_space=eval_env.action_space,
        hidden_size=1024,
        depth=2
    )

    optimizer = torch.optim.Adam(actor.parameters(),
                                  lr=lr,
                                  weight_decay=weight_decay)

    states_tensor_with_returns = torch.cat((states_tensor, torch.tensor(returns_input, dtype=torch.float32).to(device).unsqueeze(1)), dim=1)

    train_loader = DataLoader(TensorDataset(states_tensor_with_returns, actions_tensor),
                              batch_size=512, shuffle=True)

    actor.to(device)

    train_losses = []
    max_eval_score = float('-inf')

    eval_scores = []
    eval_stds = []

    for epoch in range(epochs):
        epoch_loss = 0.0
        actor.train()
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()

            loss = mle_loss(actor, x_batch, y_batch)
            loss.backward()

            optimizer.step()

            epoch_loss += loss.item()

        print('Epoch loss: ', epoch_loss)
        train_losses.append(epoch_loss / len(train_loader))

        if epoch % 10 == 0:
            results = evaluate_on_env(actor, device, eval_env, desired_return, num_eval_ep=5, max_test_ep_len=1000,
                                      state_mean=states_mean, state_std=states_std, render=False, state_normalization=True)
            eval_d4rl_score = get_normalized_score(results['eval/avg_reward']) * 100
            eval_d4rl_std = get_normalized_score(results['eval/std_returns']) * 100
            eval_scores.append(eval_d4rl_score)
            eval_stds.append(eval_d4rl_std)

            print(f'Epoch {epoch}, Average score: {eval_d4rl_score}')
            print(f'Std score: {eval_d4rl_std}')

            max_eval_score = max(max_eval_score, eval_d4rl_score)

    save_model(actor, dataset_name)

    avg_train_loss = sum(train_losses) / len(train_losses)
    mean_last_10_scores = np.mean(eval_scores[-10:])
    mean_last_10_stds = np.mean(eval_stds[-10:])

    print(f"\nMean of the last 10 Average Scores for {dataset_name}: {mean_last_10_scores}")
    print(f"Mean of the last 10 Std Scores for {dataset_name}: {mean_last_10_stds}")

    results_table.add_row([dataset_name, mean_last_10_scores, mean_last_10_stds])

print("\nFinal Results Table:")
print(results_table)
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Training on dataset: halfcheetah-medium-replay-v2
# load datafile: 100%|██████████| 11/11 [00:00<00:00, 22.28it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/halfcheetah_medium_replay-v2.hdf5
# Epoch loss:  2178.096083164215
# sum of reward per episode:  -146.8032796192374
# sum of reward per episode:  -146.27299306945875
# sum of reward per episode:  -145.03391390906364
# sum of reward per episode:  -147.46537350394024
# sum of reward per episode:  -147.1072622595697
# Epoch 0, Average score: 1.0764435134900152
# Std score: 2.26356738458784
# Epoch loss:  1779.3889260292053
# Epoch loss:  1462.7863652706146
# Epoch loss:  1215.563713312149
# Epoch loss:  1039.935843706131
# Epoch loss:  932.7702417373657
# Epoch loss:  871.3230186700821
# Epoch loss:  834.4584321975708
# Epoch loss:  809.2603257894516
# Epoch loss:  787.5444891452789
# Epoch loss:  770.7840523719788
# sum of reward per episode:  -84.56240877214813
# sum of reward per episode:  -42.81202037741112
# sum of reward per episode:  -85.66370406716743
# sum of reward per episode:  -85.57085737172348
# sum of reward per episode:  -81.95332630656775
# Epoch 10, Average score: 1.6436854466095805
# Std score: 2.391290456800246
# Epoch loss:  755.0998742580414
# Epoch loss:  738.9683036804199
# Epoch loss:  722.8988606929779
# Epoch loss:  710.485310792923
# Epoch loss:  696.5493936538696
# Epoch loss:  684.7443808317184
# Epoch loss:  672.1200616359711
# Epoch loss:  659.7176532745361
# Epoch loss:  648.1524468660355
# Epoch loss:  637.1931602954865
# sum of reward per episode:  80.92776152863213
# sum of reward per episode:  -83.97752716902991
# sum of reward per episode:  3844.8972742675282
# sum of reward per episode:  4047.228720803379
# sum of reward per episode:  4182.68301638591
# Epoch 20, Average score: 21.70351963804899
# Std score: 18.17412378316787
# Epoch loss:  625.5399298667908
# Epoch loss:  612.877668261528
# Epoch loss:  600.8158421516418
# Epoch loss:  591.0836850404739
# Epoch loss:  581.0737877488136
# Epoch loss:  568.3367130160332
# Epoch loss:  559.577528834343
# Epoch loss:  548.0468919873238
# Epoch loss:  538.7172788977623
# Epoch loss:  525.3297672867775
# sum of reward per episode:  2228.3447503705283
# sum of reward per episode:  1577.2277112259808
# sum of reward per episode:  4048.166352237507
# sum of reward per episode:  3984.967874779763
# sum of reward per episode:  214.43889974951148
# Epoch 30, Average score: 21.673534315205725
# Std score: 14.04580596205488
# Epoch loss:  516.8115853667259
# Epoch loss:  504.27762573957443
# Epoch loss:  495.4399964809418
# Epoch loss:  483.8756335377693
# Epoch loss:  475.2060444355011
# Epoch loss:  465.34769809246063
# Epoch loss:  456.2589509487152
# Epoch loss:  445.4561890363693
# Epoch loss:  434.01458317041397
# Epoch loss:  425.0668988227844
# sum of reward per episode:  2229.4229343761526
# sum of reward per episode:  -734.6160206358727
# sum of reward per episode:  3886.0302224699385
# sum of reward per episode:  3655.137484264574
# sum of reward per episode:  4181.852785007177
# Epoch 40, Average score: 23.54975667418709
# Std score: 16.89626809656587
# Epoch loss:  416.31565099954605
# Epoch loss:  405.3954300880432
# Epoch loss:  395.5906608700752
# Epoch loss:  387.24559181928635
# Epoch loss:  377.142283141613
# Epoch loss:  368.1687324643135
# Epoch loss:  360.99134349823
# Epoch loss:  349.324018239975
# Epoch loss:  339.6586115062237
# Epoch loss:  331.0238553583622
# sum of reward per episode:  3712.239480100347
# sum of reward per episode:  3880.5406167547653
# sum of reward per episode:  3188.983926126092
# sum of reward per episode:  3547.8875975944306
# sum of reward per episode:  3750.8951272074096
# Epoch 50, Average score: 31.383263320703968
# Std score: 4.177818505723298
# Epoch loss:  321.1640523672104
# Epoch loss:  312.1771582067013
# Epoch loss:  304.71783661842346
# Epoch loss:  296.2201495617628
# Epoch loss:  288.8604582697153
# Epoch loss:  278.3621194958687
# Epoch loss:  269.79228138923645
# Epoch loss:  261.900313898921
# Epoch loss:  252.03992433845997
# Epoch loss:  245.3779093027115
# sum of reward per episode:  3642.7911760502884
# sum of reward per episode:  3475.3740285020813
# sum of reward per episode:  3288.8803944915253
# sum of reward per episode:  3706.015472979281
# sum of reward per episode:  3068.900395521927
# Epoch 60, Average score: 29.9357041938646
# Std score: 4.141007317564994
# Epoch loss:  237.57501973211765
# Epoch loss:  229.18784306943417
# Epoch loss:  220.9138090312481
# Epoch loss:  212.31735725700855
# Epoch loss:  205.67460864782333
# Epoch loss:  197.50699050538242
# Epoch loss:  188.7264359742403
# Epoch loss:  181.0626298598945
# Epoch loss:  172.9998718202114
# Epoch loss:  167.3636296838522
# sum of reward per episode:  3235.170241837998
# sum of reward per episode:  3071.701654955913
# sum of reward per episode:  2853.5476017637375
# sum of reward per episode:  2646.0965291246175
# sum of reward per episode:  3014.283113892279
# Epoch 70, Average score: 26.132033969038766
# Std score: 3.871391646137328
# Epoch loss:  157.72438311576843
# Epoch loss:  150.65341904945672
# Epoch loss:  143.75273078680038
# Epoch loss:  138.39443456288427
# Epoch loss:  129.20646815560758
# Epoch loss:  122.3441628664732
# Epoch loss:  113.95371784828603
# Epoch loss:  107.83881301246583
# Epoch loss:  101.77085614204407
# Epoch loss:  93.31006608624011
# sum of reward per episode:  2360.8091392390857
# sum of reward per episode:  1647.1333575534077
# sum of reward per episode:  3086.0529278140034
# sum of reward per episode:  1613.3146983134245
# sum of reward per episode:  1499.999435484503
# Epoch 80, Average score: 18.70001933496007
# Std score: 7.123170580323454
# Epoch loss:  89.33510849438608
# Epoch loss:  78.38079088088125
# Epoch loss:  73.20421133842319
# Epoch loss:  65.09945292770863
# Epoch loss:  59.15892977267504
# Epoch loss:  51.43285166379064
# Epoch loss:  44.64497720822692
# Epoch loss:  37.26491809356958
# Epoch loss:  33.711654151789844
# Epoch loss:  25.173043373972178
# sum of reward per episode:  3413.500206263523
# sum of reward per episode:  3681.3918802481226
# sum of reward per episode:  3257.1951026477345
# sum of reward per episode:  3721.0048293113023
# sum of reward per episode:  3732.2959851216424
# Epoch 90, Average score: 30.94000149542963
# Std score: 3.79976020620452
# Epoch loss:  18.91115394514054
# Epoch loss:  15.977544190362096
# Epoch loss:  8.361330543644726
# Epoch loss:  2.5016424003988504
# Epoch loss:  -4.514180559664965
# Epoch loss:  -11.340782322920859
# Epoch loss:  -15.52584741730243
# Epoch loss:  -24.838957431726158
# Epoch loss:  -27.072666285559535
# Model saved to trained_mle_model_halfcheetah-medium-replay-v2.pth
#
# Mean of the last 10 Average Scores for halfcheetah-medium-replay-v2: 20.673796190153844
# Mean of the last 10 Std Scores for halfcheetah-medium-replay-v2: 7.688420393913032
# Training on dataset: hopper-medium-replay-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/hopper_medium_replay-v2.hdf5 to /root/.d4rl/datasets/hopper_medium_replay-v2.hdf5
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# load datafile: 100%|██████████| 11/11 [00:00<00:00, 18.20it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/hopper_medium_replay-v2.hdf5
# Epoch loss:  2062.939960002899
# sum of reward per episode:  828.4849799780503
# sum of reward per episode:  779.5905362400079
# sum of reward per episode:  849.4576710666545
# sum of reward per episode:  773.016383488386
# sum of reward per episode:  913.0786868028214
# Epoch 0, Average score: 26.08631417439602
# Std score: 2.1934090179049703
# Epoch loss:  1508.2142354249954
# Epoch loss:  1240.4134732484818
# Epoch loss:  1142.6536415815353
# Epoch loss:  1096.6051236391068
# Epoch loss:  1065.4656705856323
# Epoch loss:  1043.3542442321777
# Epoch loss:  1024.122771024704
# Epoch loss:  1006.7005695104599
# Epoch loss:  993.750186085701
# Epoch loss:  980.6769659519196
# sum of reward per episode:  957.1853394980772
# sum of reward per episode:  975.9235497895651
# sum of reward per episode:  975.3799643139535
# sum of reward per episode:  958.6689389351687
# sum of reward per episode:  976.7413827011513
# Epoch 10, Average score: 30.389619506320397
# Std score: 0.8958622195815403
# Epoch loss:  970.3364434242249
# Epoch loss:  959.9777969121933
# Epoch loss:  949.6404609680176
# Epoch loss:  941.1468760967255
# Epoch loss:  932.331327021122
# Epoch loss:  924.4869585633278
# Epoch loss:  916.7236694693565
# Epoch loss:  910.5432894825935
# Epoch loss:  903.4374389052391
# Epoch loss:  897.4120217561722
# sum of reward per episode:  1144.9736327808137
# sum of reward per episode:  1190.5596672647466
# sum of reward per episode:  1148.0020194868464
# sum of reward per episode:  1167.5031638524915
# sum of reward per episode:  1188.399865257654
# Epoch 20, Average score: 36.50740752949754
# Std score: 1.2147768829898156
# Epoch loss:  890.4044635295868
# Epoch loss:  884.8582046031952
# Epoch loss:  879.9552661776543
# Epoch loss:  874.7027210593224
# Epoch loss:  868.1966073513031
# Epoch loss:  863.6279584765434
# Epoch loss:  859.6141114234924
# Epoch loss:  855.444423019886
# Epoch loss:  850.343668460846
# Epoch loss:  845.209025979042
# sum of reward per episode:  1457.2047198525643
# sum of reward per episode:  1390.9594050990481
# sum of reward per episode:  977.8016092527705
# sum of reward per episode:  1621.453092751398
# sum of reward per episode:  934.524780238649
# Epoch 30, Average score: 39.84121122295624
# Std score: 8.991597855942432
# Epoch loss:  843.5208844542503
# Epoch loss:  837.5389503240585
# Epoch loss:  835.7292569875717
# Epoch loss:  831.3396574854851
# Epoch loss:  827.8653995394707
# Epoch loss:  823.1032537221909
# Epoch loss:  820.5951509475708
# Epoch loss:  818.0816105604172
# Epoch loss:  813.6241926550865
# Epoch loss:  810.1729021668434
# sum of reward per episode:  1200.346685116218
# sum of reward per episode:  846.0113706831213
# sum of reward per episode:  882.5781974667128
# sum of reward per episode:  946.0669622511653
# sum of reward per episode:  1389.2101420479432
# Epoch 40, Average score: 32.97253451288841
# Std score: 7.039705651752924
# Epoch loss:  806.6452814340591
# Epoch loss:  803.6058762669563
# Epoch loss:  800.6695231795311
# Epoch loss:  797.9531360268593
# Epoch loss:  796.8149296045303
# Epoch loss:  792.3479445576668
# Epoch loss:  790.9039589166641
# Epoch loss:  787.6651852726936
# Epoch loss:  785.4734721779823
# Epoch loss:  783.5764197707176
# sum of reward per episode:  1851.312264118416
# sum of reward per episode:  1745.8076645537903
# sum of reward per episode:  1154.1682427012056
# sum of reward per episode:  1546.7217260719463
# sum of reward per episode:  1470.2904072492904
# Epoch 50, Average score: 48.360651367950766
# Std score: 8.049558211353135
# Epoch loss:  779.4837930798531
# Epoch loss:  777.2543689608574
# Epoch loss:  775.4827423095703
# Epoch loss:  774.0088800787926
# Epoch loss:  769.9144255518913
# Epoch loss:  768.9426352977753
# Epoch loss:  766.8874078392982
# Epoch loss:  762.4867415428162
# Epoch loss:  760.8496542572975
# Epoch loss:  759.9324472546577
# sum of reward per episode:  962.0543384405711
# sum of reward per episode:  962.0918577500215
# sum of reward per episode:  1080.7792161183447
# sum of reward per episode:  809.0897655171804
# sum of reward per episode:  878.7436394939128
# Epoch 60, Average score: 29.460831673365075
# Std score: 3.4279733415886353
# Epoch loss:  757.8083949685097
# Epoch loss:  755.4699441790581
# Epoch loss:  754.6271520853043
# Epoch loss:  750.6205796599388
# Epoch loss:  750.2966002225876
# Epoch loss:  746.9620776772499
# Epoch loss:  744.6921862959862
# Epoch loss:  742.81220972538
# Epoch loss:  743.0133331418037
# Epoch loss:  739.9869009852409
# sum of reward per episode:  1546.7040800150776
# sum of reward per episode:  1186.7562138906105
# sum of reward per episode:  939.3617922215998
# sum of reward per episode:  817.6781696913539
# sum of reward per episode:  835.981929662782
# Epoch 70, Average score: 33.35518895765585
# Std score: 9.051733444301505
# Epoch loss:  737.5144894123077
# Epoch loss:  738.2239593863487
# Epoch loss:  733.8350968956947
# Epoch loss:  732.2483075261116
# Epoch loss:  732.3788639903069
# Epoch loss:  728.1133111715317
# Epoch loss:  726.9060645699501
# Epoch loss:  728.0849915742874
# Epoch loss:  724.3953419923782
# Epoch loss:  721.8444865942001
# sum of reward per episode:  1096.433787618526
# sum of reward per episode:  1504.1683716642754
# sum of reward per episode:  1229.6803694632604
# sum of reward per episode:  1077.6622324021084
# sum of reward per episode:  1140.7572620383319
# Epoch 80, Average score: 37.79337480834678
# Std score: 5.424942262229909
# Epoch loss:  723.4987741708755
# Epoch loss:  720.8195122480392
# Epoch loss:  719.6276063919067
# Epoch loss:  716.4121150970459
# Epoch loss:  716.4871137738228
# Epoch loss:  714.8758090734482
# Epoch loss:  711.8751020431519
# Epoch loss:  710.2323285341263
# Epoch loss:  709.179966211319
# Epoch loss:  707.4550926685333
# sum of reward per episode:  778.1072957368353
# sum of reward per episode:  1330.7857911419549
# sum of reward per episode:  842.7429151176227
# sum of reward per episode:  1081.050198436313
# sum of reward per episode:  2386.403679226643
# Epoch 90, Average score: 40.069482522431635
# Std score: 18.588044997677933
# Epoch loss:  708.0937890410423
# Epoch loss:  705.367169201374
# Epoch loss:  704.4653840661049
# Epoch loss:  702.9609453678131
# Epoch loss:  700.7867276668549
# Epoch loss:  700.3028349280357
# Epoch loss:  698.6796548366547
# Epoch loss:  697.2017282247543
# Epoch loss:  694.7017070055008
# Model saved to trained_mle_model_hopper-medium-replay-v2.pth
#
# Mean of the last 10 Average Scores for hopper-medium-replay-v2: 35.48366162758087
# Mean of the last 10 Std Scores for hopper-medium-replay-v2: 6.48776038853228
# Training on dataset: walker2d-medium-replay-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/walker2d_medium_replay-v2.hdf5 to /root/.d4rl/datasets/walker2d_medium_replay-v2.hdf5
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Walker2d-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# load datafile: 100%|██████████| 11/11 [00:00<00:00, 15.82it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/walker2d_medium_replay-v2.hdf5
# Epoch loss:  3122.756091117859
# sum of reward per episode:  476.06248989656314
# sum of reward per episode:  481.7653150595763
# sum of reward per episode:  479.6080834844414
# sum of reward per episode:  472.1760949436474
# sum of reward per episode:  474.36366178546
# Epoch 0, Average score: 10.350689950597491
# Std score: 0.04022535484779212
# Epoch loss:  2345.208680152893
# Epoch loss:  1810.3322427272797
# Epoch loss:  1505.6782441139221
# Epoch loss:  1365.6612771749496
# Epoch loss:  1295.6963382959366
# Epoch loss:  1245.960938692093
# Epoch loss:  1204.1584378480911
# Epoch loss:  1171.240723848343
# Epoch loss:  1140.1436762809753
# Epoch loss:  1112.850559592247
# sum of reward per episode:  2461.7007453326946
# sum of reward per episode:  2703.305175837917
# sum of reward per episode:  2277.457703815891
# sum of reward per episode:  2247.2892212214765
# sum of reward per episode:  655.2731046380444
# Epoch 10, Average score: 45.03429206257535
# Std score: 15.764314120798387
# Epoch loss:  1085.1759390830994
# Epoch loss:  1061.3992849588394
# Epoch loss:  1037.3406413793564
# Epoch loss:  1014.7521257400513
# Epoch loss:  995.5891095399857
# Epoch loss:  974.6675822734833
# Epoch loss:  954.4020683765411
# Epoch loss:  935.98859167099
# Epoch loss:  917.183111667633
# Epoch loss:  900.4212070703506
# sum of reward per episode:  727.5535027542298
# sum of reward per episode:  1278.7868597301458
# sum of reward per episode:  734.1632558637525
# sum of reward per episode:  3821.2242905298317
# sum of reward per episode:  3349.0808443827395
# Epoch 20, Average score: 43.14255467454628
# Std score: 28.989327381970153
# Epoch loss:  882.1610292196274
# Epoch loss:  864.6109181642532
# Epoch loss:  850.9322158098221
# Epoch loss:  834.9261083602905
# Epoch loss:  817.4326093196869
# Epoch loss:  805.2310201525688
# Epoch loss:  789.8852722644806
# Epoch loss:  775.3711024522781
# Epoch loss:  760.7754351496696
# Epoch loss:  749.289970934391
# sum of reward per episode:  1445.0487073552224
# sum of reward per episode:  2356.925597685564
# sum of reward per episode:  3824.581279490117
# sum of reward per episode:  3856.088618062431
# sum of reward per episode:  1182.4629357195397
# Epoch 30, Average score: 55.142100666197656
# Std score: 24.719663018669973
# Epoch loss:  734.9117932915688
# Epoch loss:  722.1736801862717
# Epoch loss:  710.5681021809578
# Epoch loss:  696.6598198413849
# Epoch loss:  685.8736007213593
# Epoch loss:  672.7085775732994
# Epoch loss:  661.9209510684013
# Epoch loss:  650.8579462766647
# Epoch loss:  638.8842027783394
# Epoch loss:  630.1379806399345
# sum of reward per episode:  3737.947473972629
# sum of reward per episode:  850.3479730928126
# sum of reward per episode:  1025.4647851777725
# sum of reward per episode:  1163.3615511964545
# sum of reward per episode:  2159.4120163274274
# Epoch 40, Average score: 38.89796840299071
# Std score: 23.407775427874714
# Epoch loss:  616.5717939734459
# Epoch loss:  609.9471572041512
# Epoch loss:  594.5612852573395
# Epoch loss:  587.5389660894871
# Epoch loss:  576.1150619387627
# Epoch loss:  565.7189446091652
# Epoch loss:  556.2940976023674
# Epoch loss:  546.0585407614708
# Epoch loss:  538.2949180603027
# Epoch loss:  530.8326966166496
# sum of reward per episode:  606.3097987562985
# sum of reward per episode:  572.3595993794421
# sum of reward per episode:  553.8270812482021
# sum of reward per episode:  507.80606330207416
# sum of reward per episode:  533.9211852719612
# Epoch 50, Average score: 12.050868784882773
# Std score: 0.6939720999884589
# Epoch loss:  520.3603724241257
# Epoch loss:  510.9369401037693
# Epoch loss:  501.89815524220467
# Epoch loss:  494.76203459501266
# Epoch loss:  483.8291362822056
# Epoch loss:  478.18400049209595
# Epoch loss:  467.2107375860214
# Epoch loss:  461.0350497364998
# Epoch loss:  452.23071736097336
# Epoch loss:  442.98245763778687
# sum of reward per episode:  993.8739366618843
# sum of reward per episode:  811.809207665917
# sum of reward per episode:  1493.572982486422
# sum of reward per episode:  571.3621633373889
# sum of reward per episode:  110.50236525737199
# Epoch 60, Average score: 17.308910276221265
# Std score: 9.929662815798093
# Epoch loss:  437.9233884215355
# Epoch loss:  426.5424711406231
# Epoch loss:  418.82039177417755
# Epoch loss:  413.8459649384022
# Epoch loss:  405.77895621955395
# Epoch loss:  398.22232058644295
# Epoch loss:  391.79266425967216
# Epoch loss:  385.0773166716099
# Epoch loss:  376.0908321738243
# Epoch loss:  370.2437268048525
# sum of reward per episode:  1058.9715859374764
# sum of reward per episode:  1804.257018696517
# sum of reward per episode:  2860.0413137034006
# sum of reward per episode:  883.195102895301
# sum of reward per episode:  3003.376492431192
# Epoch 70, Average score: 41.83134226084341
# Std score: 19.17115203764646
# Epoch loss:  360.9109814763069
# Epoch loss:  357.369163274765
# Epoch loss:  348.37604047358036
# Epoch loss:  341.12520353496075
# Epoch loss:  335.17932507395744
# Epoch loss:  329.9672410786152
# Epoch loss:  324.06238808482885
# Epoch loss:  316.26542338728905
# Epoch loss:  311.92548332363367
# Epoch loss:  302.7910052612424
# sum of reward per episode:  924.2846921499417
# sum of reward per episode:  1611.3111465972763
# sum of reward per episode:  1492.097068114612
# sum of reward per episode:  2942.072893460415
# sum of reward per episode:  664.9223019676391
# Epoch 80, Average score: 33.22626725191322
# Std score: 17.164230647413262
# Epoch loss:  300.0691693201661
# Epoch loss:  291.169475838542
# Epoch loss:  285.5961699485779
# Epoch loss:  282.1420997455716
# Epoch loss:  275.28844498842955
# Epoch loss:  267.3732955083251
# Epoch loss:  262.8391650021076
# Epoch loss:  257.1360659971833
# Epoch loss:  251.66434755921364
# Epoch loss:  246.2445291299373
# sum of reward per episode:  823.8474226325733
# sum of reward per episode:  42.01959673017345
# sum of reward per episode:  933.259504669023
# sum of reward per episode:  3746.825357107143
# sum of reward per episode:  998.747264105992
# Epoch 90, Average score: 28.47755422523602
# Std score: 27.554676024907227
# Epoch loss:  241.714345023036
# Epoch loss:  234.72672651708126
# Epoch loss:  226.90826088748872
# Epoch loss:  222.6529535781592
# Epoch loss:  219.29924725927413
# Epoch loss:  214.2847631573677
# Epoch loss:  206.6848546974361
# Epoch loss:  206.26056838408113
# Epoch loss:  199.00230829045177
# Model saved to trained_mle_model_walker2d-medium-replay-v2.pth
#
# Mean of the last 10 Average Scores for walker2d-medium-replay-v2: 32.54625485560042
# Mean of the last 10 Std Scores for walker2d-medium-replay-v2: 16.74349989299145
#
# Final Results Table:
# +------------------------------+-----------------------------+-------------------------+
# |           Dataset            | Mean Last 10 Average Scores | Mean Last 10 Std Scores |
# +------------------------------+-----------------------------+-------------------------+
# | halfcheetah-medium-replay-v2 |      20.673796190153844     |    7.688420393913032    |
# |   hopper-medium-replay-v2    |      35.48366162758087      |     6.48776038853228    |
# |  walker2d-medium-replay-v2   |      32.54625485560042      |    16.74349989299145    |
# +------------------------------+-----------------------------+-------------------------+
