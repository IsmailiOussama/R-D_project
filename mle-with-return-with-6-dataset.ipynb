# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/Project_R&D')

# %% [markdown]
# # d4rl utils

# %%
# !pip install gymnasium[mujoco]
# Out:
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.10/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Collecting mujoco>=2.3.3 (from gymnasium[mujoco])
#   Downloading mujoco-3.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (2.36.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.0.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (1.11.0)
# Collecting glfw (from mujoco>=2.3.3->gymnasium[mujoco])
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (3.1.7)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[mujoco]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[mujoco]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[mujoco]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[mujoco]) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[mujoco]) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[mujoco]) (2.4.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (2024.9.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (3.21.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.0->gymnasium[mujoco]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.0->gymnasium[mujoco]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.0->gymnasium[mujoco]) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.0->gymnasium[mujoco]) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.0->gymnasium[mujoco]) (2024.2.0)
# Downloading mujoco-3.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 63.2 MB/s eta 0:00:00a 0:00:01
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 20.2 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.8.0 mujoco-3.2.7

# %%
# !pip install torch numpy matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy) (2024.2.0)

# %%
# !pip install just-d4rl
# Out:
# Requirement already satisfied: just-d4rl in /usr/local/lib/python3.10/dist-packages (0.2407.5)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from just-d4rl) (3.12.1)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from just-d4rl) (4.67.1)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.10/dist-packages (from just-d4rl) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from h5py>=3.11.0->just-d4rl) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2->just-d4rl) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->just-d4rl) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2->just-d4rl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2->just-d4rl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2->just-d4rl) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->just-d4rl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2->just-d4rl) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2->just-d4rl) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.3->h5py>=3.11.0->just-d4rl) (2024.2.0)

# %%
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: stable_baselines3 in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (0.29.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable_baselines3) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable_baselines3) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable_baselines3) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable_baselines3) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable_baselines3) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable_baselines3) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20->stable_baselines3) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20->stable_baselines3) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->stable_baselines3) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.20->stable_baselines3) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.20->stable_baselines3) (2024.2.0)

# %% [markdown]
# # MLE_Training_with_6_datasets
# ## With returns

# %%
import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from just_d4rl import D4RLDataset, d4rl_offline_dataset, D4RLScoreNormalizer
import gymnasium as gym
import matplotlib.pyplot as plt
import torch
import numpy as np
import torch.nn as nn
from stable_baselines3.common import policies
from stable_baselines3.common.torch_layers import FlattenExtractor, MlpExtractor
import collections
from torch.utils.data import DataLoader, TensorDataset
from prettytable import PrettyTable

# Define the MLE model (UnconditionalPolicy)
class UnconditionalPolicy(policies.ActorCriticPolicy):
    def __init__(
        self,
        observation_space,
        action_space,
        hidden_size=1024,
        depth=2,
        learning_rate=1e-3,
        dropout_p=0.1
    ):
        net_arch = dict(
            pi=[hidden_size] * depth,  # policy network architecture
            vf=[64]  # Small value network (we don't use it but need it)
        )

        super().__init__(
            observation_space=observation_space,
            action_space=action_space,
            lr_schedule=lambda _: learning_rate,
            net_arch=net_arch,
            activation_fn=nn.ReLU,
            features_extractor_class=FlattenExtractor,
            optimizer_class=torch.optim.Adam
        )

    def _build(self, lr_schedule):
        self.features_extractor = self.features_extractor_class(self.observation_space)
        self.features_dim = self.features_extractor.features_dim

        self.mlp_extractor = MlpExtractor(
            self.features_dim,
            net_arch=self.net_arch,
            activation_fn=self.activation_fn,
        )

        self.value_net = nn.Linear(self.mlp_extractor.latent_dim_vf, 1)

        latent_dim_pi = self.mlp_extractor.latent_dim_pi
        self.action_net, self.log_std = self.action_dist.proba_distribution_net(
            latent_dim=latent_dim_pi,
            log_std_init=self.log_std_init
        )

def mle_loss(policy, obs, actions):
    _, log_prob, _ = policy.evaluate_actions(obs, actions)
    return -log_prob.mean()

def evaluate_on_env(model, device, env, desired_return_target,
                    num_eval_ep=10, max_test_ep_len=1000,
                    state_mean=None, state_std=None, render=False,
                    state_normalization=True):

    eval_batch_size = 1
    results = {}
    total_reward = 0
    total_timesteps = 0

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    if state_mean is None:
        state_mean = torch.zeros((state_dim,)).to(device)
    else:
        state_mean = torch.from_numpy(state_mean).to(device)

    if state_std is None:
        state_std = torch.ones((state_dim,)).to(device)
    else:
        state_std = torch.from_numpy(state_std).to(device)

    model.eval()
    model.to(device)

    with torch.no_grad():
        return_per_ep_log = []
        all_rewards = []


        for ep in range(num_eval_ep):

            reset_result = env.reset()
            if isinstance(reset_result, tuple):  # Gymnasium style
                running_state, _ = reset_result
            else:  # Old Gym style
                running_state = reset_result

            running_reward = 0
            reward_per_ep = 0
            running_reward_log = []
            desired_return = desired_return_target
            for t in range(max_test_ep_len):
                total_timesteps += 1
                desired_return -= running_reward*0.001

                state = torch.from_numpy(running_state).to(device, dtype=torch.float32)
                if state_normalization:
                    state = (state - state_mean) / state_std

                if len(state.shape) == 1:
                    state = state.unsqueeze(0)


                state = torch.cat([state, torch.from_numpy(np.array(desired_return)).to(device, dtype=torch.float32).reshape((1,1))], dim=1)

                actions = model._predict(state, deterministic=True)

                step_result = env.step(actions.cpu().numpy().flatten())
                if len(step_result) == 5:  # Gymnasium style
                    running_state, running_reward, terminated, truncated, _ = step_result
                    done = terminated or truncated
                else:  # Old Gym style
                    running_state, running_reward, done, _ = step_result

                running_reward_log.append(running_reward)

                total_reward += running_reward
                reward_per_ep += running_reward

                if render:
                    env.render()
                if done:
                    print('sum of reward per episode: ', reward_per_ep)
                    return_per_ep_log.append(reward_per_ep)
                    break

    t = np.arange(len(running_reward_log))
    plt.plot(t, np.array(running_reward_log), 'b')
    plt.show()

    results['eval/avg_reward'] = total_reward / num_eval_ep
    results['eval/avg_ep_len'] = total_timesteps / num_eval_ep
    results['eval/std_returns'] = np.std(return_per_ep_log)
    results['eval/all_rewards'] = all_rewards

    return results

def flatten_traj(paths):
    states_list = []
    actions_list = []

    for p in paths:
        states_list.append(p['observations'])
        actions_list.append(p['actions'])

    states = np.concatenate(states_list)
    actions = np.concatenate(actions_list)

    return(states, actions)

def save_model(model, dataset_name):
    model_filename = f"trained_mle_model_{dataset_name}.pth"
    torch.save(model.state_dict(), model_filename)
    print(f"Model saved to {model_filename}")

# List of datasets
dataset_list = [
    ("halfcheetah-medium-v2", 12000*0.001),
    ("halfcheetah-medium-expert-v2", 12000*0.001),
    ("hopper-medium-v2", 3600*0.001),
    ("hopper-medium-expert-v2", 3600*0.001),
    ("walker2d-medium-v2", 5000*0.001),
    ("walker2d-medium-expert-v2", 5000*0.001)

]

results_table = PrettyTable()
results_table.field_names = ["Dataset", "Mean Last 10 Average Scores", "Mean Last 10 Std Scores"]

lr = 5e-4
weight_decay = 1e-4
epochs = 100
device = 'cuda'

for dataset_name, desired_return in dataset_list:
    print(f"Training on dataset: {dataset_name}")

    eval_env = gym.make(dataset_name.split('-')[0].replace('halfcheetah', 'HalfCheetah').replace('hopper', 'Hopper').replace('walker2d', 'Walker2d') + '-v4')

    dataset = d4rl_offline_dataset(dataset_name)
    get_normalized_score = D4RLScoreNormalizer(dataset_name)

    states = dataset['observations']
    actions = dataset['actions']

    act_dim = actions.shape[1]
    obs_dim = states.shape[1]

    N = dataset['rewards'].shape[0]
    data_ = collections.defaultdict(list)

    use_timeouts = False
    if 'timeouts' in dataset:
        use_timeouts = True

    episode_step = 0
    paths = []
    for i in range(N):
        done_bool = bool(dataset['terminals'][i])
        if use_timeouts:
            final_timestep = dataset['timeouts'][i]
        else:
            final_timestep = (episode_step == 1000-1)
        for k in ['observations', 'next_observations', 'actions', 'rewards', 'terminals']:
            data_[k].append(dataset[k][i])
        if done_bool or final_timestep:
            episode_step = 0
            episode_data = {}
            for k in data_:
                episode_data[k] = np.array(data_[k])
            paths.append(episode_data)
            data_ = collections.defaultdict(list)
        episode_step += 1

    gamma = 1.0
    returns_input = []

    for path in paths:
        return_sum = 0
        returns_per_traj = np.zeros_like(path['rewards'])
        for t in reversed(range(len(path['rewards']))):
            return_sum = gamma * return_sum + path['rewards'][t]*0.001
            returns_per_traj[t] = return_sum
        returns_input.append(returns_per_traj)
    returns_input = np.concatenate(returns_input)

    states_input, actions_input = flatten_traj(paths)

    states_mean = states_input.mean(axis=0)
    states_std = states_input.std(axis=0) + 1e-6

    normalized_states = (states_input - states_mean) / states_std

    states_tensor = torch.tensor(normalized_states, dtype=torch.float32).to(device)
    actions_tensor = torch.tensor(actions_input, dtype=torch.float32).to(device)

    augmented_obs_space = gym.spaces.Box(
        low=np.concatenate([eval_env.observation_space.low, [-np.inf]]),
        high=np.concatenate([eval_env.observation_space.high, [np.inf]]),
        shape=(eval_env.observation_space.shape[0] + 1,),
        dtype=np.float32
    )

    actor = UnconditionalPolicy(
        observation_space=augmented_obs_space,
        action_space=eval_env.action_space,
        hidden_size=1024,
        depth=2
    )

    optimizer = torch.optim.Adam(actor.parameters(),
                                  lr=lr,
                                  weight_decay=weight_decay)

    states_tensor_with_returns = torch.cat((states_tensor, torch.tensor(returns_input, dtype=torch.float32).to(device).unsqueeze(1)), dim=1)

    train_loader = DataLoader(TensorDataset(states_tensor_with_returns, actions_tensor),
                              batch_size=512, shuffle=True)

    actor.to(device)

    train_losses = []
    max_eval_score = float('-inf')

    eval_scores = []
    eval_stds = []

    for epoch in range(epochs):
        epoch_loss = 0.0
        actor.train()
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()

            loss = mle_loss(actor, x_batch, y_batch)
            loss.backward()

            optimizer.step()

            epoch_loss += loss.item()

        print('Epoch loss: ', epoch_loss)
        train_losses.append(epoch_loss / len(train_loader))

        if epoch % 5 == 0:
            results = evaluate_on_env(actor, device, eval_env, desired_return, num_eval_ep=5, max_test_ep_len=1000,
                                      state_mean=states_mean, state_std=states_std, render=False, state_normalization=True)
            eval_d4rl_score = get_normalized_score(results['eval/avg_reward']) * 100
            eval_d4rl_std = get_normalized_score(results['eval/std_returns']) * 100
            eval_scores.append(eval_d4rl_score)
            eval_stds.append(eval_d4rl_std)

            print(f'Epoch {epoch}, Average score: {eval_d4rl_score}')
            print(f'Std score: {eval_d4rl_std}')

            max_eval_score = max(max_eval_score, eval_d4rl_score)

    save_model(actor, dataset_name)

    avg_train_loss = sum(train_losses) / len(train_losses)
    mean_last_10_scores = np.mean(eval_scores[-10:])
    mean_last_10_stds = np.mean(eval_stds[-10:])

    print(f"\nMean of the last 10 Average Scores for {dataset_name}: {mean_last_10_scores}")
    print(f"Mean of the last 10 Std Scores for {dataset_name}: {mean_last_10_stds}")

    results_table.add_row([dataset_name, mean_last_10_scores, mean_last_10_stds])

print("\nFinal Results Table:")
print(results_table)
# Out:
# Training on dataset: halfcheetah-medium-v2
# load datafile: 100%|██████████| 21/21 [00:02<00:00, 10.22it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/halfcheetah_medium-v2.hdf5
# Epoch loss:  5836.930167883635
# sum of reward per episode:  4509.098299643974
# sum of reward per episode:  4529.016557713212
# sum of reward per episode:  -77.59159627308182
# sum of reward per episode:  -76.99790704808427
# sum of reward per episode:  4640.784789836349
# Epoch 0, Average score: 24.04347930122403
# Std score: 20.5574484115942
# Epoch loss:  -1714.3294509332627
# Epoch loss:  -3661.0140501260757
# Epoch loss:  -3945.376901745796
# Epoch loss:  -4078.874261856079
# Epoch loss:  -4170.612659096718
# sum of reward per episode:  5119.32935200866
# sum of reward per episode:  5126.088892322439
# sum of reward per episode:  4876.4036664276955
# sum of reward per episode:  4957.650774502126
# sum of reward per episode:  5119.1586899015365
# Epoch 5, Average score: 42.850008430583095
# Std score: 3.0900446169583566
# Epoch loss:  -4239.189702153206
# Epoch loss:  -4294.403740167618
# Epoch loss:  -4341.098509192467
# Epoch loss:  -4385.502468466759
# Epoch loss:  -4418.06288599968
# sum of reward per episode:  4937.191833513674
# sum of reward per episode:  4950.225525828642
# sum of reward per episode:  4953.366398765937
# sum of reward per episode:  4913.462946439721
# sum of reward per episode:  5210.99405412815
# Epoch 10, Average score: 42.474032188323775
# Std score: 3.141750478137164
# Epoch loss:  -4444.310594797134
# Epoch loss:  -4474.246090054512
# Epoch loss:  -4499.665819525719
# Epoch loss:  -4522.57334280014
# Epoch loss:  -4542.597763538361
# sum of reward per episode:  4950.101396540355
# sum of reward per episode:  5118.67984333166
# sum of reward per episode:  4909.088698127276
# sum of reward per episode:  4928.784310840932
# sum of reward per episode:  4967.991070786778
# Epoch 15, Average score: 42.32808916262585
# Std score: 2.857269673122293
# Epoch loss:  -4561.3970720767975
# Epoch loss:  -4584.6137100458145
# Epoch loss:  -4594.17981004715
# Epoch loss:  -4614.986563205719
# Epoch loss:  -4630.657799363136
# sum of reward per episode:  4813.104673136211
# sum of reward per episode:  5048.2016324691585
# sum of reward per episode:  4702.215282719287
# sum of reward per episode:  4787.221889538437
# sum of reward per episode:  5016.274057032713
# Epoch 20, Average score: 41.51033569060102
# Std score: 3.3453760602294143
# Epoch loss:  -4636.260989785194
# Epoch loss:  -4653.524857163429
# Epoch loss:  -4670.805894732475
# Epoch loss:  -4676.445480823517
# Epoch loss:  -4690.35132086277
# sum of reward per episode:  4922.70773856224
# sum of reward per episode:  4778.7431117240785
# sum of reward per episode:  4942.895301363573
# sum of reward per episode:  4754.469396758015
# sum of reward per episode:  4912.152653992845
# Epoch 25, Average score: 41.420044068213336
# Std score: 2.8934108255365136
# Epoch loss:  -4698.432487010956
# Epoch loss:  -4709.354968905449
# Epoch loss:  -4721.210148572922
# Epoch loss:  -4729.298148870468
# Epoch loss:  -4737.547031998634
# sum of reward per episode:  4939.215722308794
# sum of reward per episode:  4843.605374715542
# sum of reward per episode:  4743.297435715597
# sum of reward per episode:  4747.135633923296
# sum of reward per episode:  4759.2841128717955
# Epoch 30, Average score: 40.97151259892104
# Std score: 2.8673954876758896
# Epoch loss:  -4746.93637752533
# Epoch loss:  -4755.717760920525
# Epoch loss:  -4763.274973750114
# Epoch loss:  -4771.487627863884
# Epoch loss:  -4778.7853491306305
# sum of reward per episode:  4921.25892757334
# sum of reward per episode:  5160.49265282014
# sum of reward per episode:  4838.49883479826
# sum of reward per episode:  4841.44825876008
# sum of reward per episode:  4940.373798637848
# Epoch 35, Average score: 42.05008616695313
# Std score: 3.2028327245697437
# Epoch loss:  -4785.721924424171
# Epoch loss:  -4790.948398470879
# Epoch loss:  -4800.945069551468
# Epoch loss:  -4807.54694545269
# Epoch loss:  -4816.5955592393875
# sum of reward per episode:  4779.61407902964
# sum of reward per episode:  4832.230055880484
# sum of reward per episode:  4991.119767271766
# sum of reward per episode:  4993.905573987528
# sum of reward per episode:  4886.4359780629
# Epoch 40, Average score: 41.697667536202005
# Std score: 2.943376600853101
# Epoch loss:  -4820.690605163574
# Epoch loss:  -4824.781336545944
# Epoch loss:  -4834.657590150833
# Epoch loss:  -4839.446911692619
# Epoch loss:  -4843.348015546799
# sum of reward per episode:  4800.252414341966
# sum of reward per episode:  4705.896673480478
# sum of reward per episode:  5075.995051755694
# sum of reward per episode:  5194.641444641805
# sum of reward per episode:  5071.332330979578
# Epoch 45, Average score: 42.285355337317405
# Std score: 3.7442684779339612
# Epoch loss:  -4850.1350420713425
# Epoch loss:  -4851.864074707031
# Epoch loss:  -4861.94393658638
# Epoch loss:  -4866.617147803307
# Epoch loss:  -4868.754556894302
# sum of reward per episode:  5017.4049236887395
# sum of reward per episode:  4870.181978583747
# sum of reward per episode:  4913.688965111722
# sum of reward per episode:  5023.526150586669
# sum of reward per episode:  4840.611284709891
# Epoch 50, Average score: 41.9910307638089
# Std score: 2.8613686530337974
# Epoch loss:  -4877.5630222558975
# Epoch loss:  -4882.150355219841
# Epoch loss:  -4887.2735023498535
# Epoch loss:  -4892.820168852806
# Epoch loss:  -4896.276162028313
# sum of reward per episode:  4690.301002341325
# sum of reward per episode:  4926.869516905048
# sum of reward per episode:  4782.225183871001
# sum of reward per episode:  4765.950720985439
# sum of reward per episode:  4840.0727231935225
# Epoch 55, Average score: 40.92782554077835
# Std score: 2.8930629493049667
# Epoch loss:  -4900.639538884163
# Epoch loss:  -4903.567558169365
# Epoch loss:  -4909.075711488724
# Epoch loss:  -4914.38468170166
# Epoch loss:  -4917.662933349609
# sum of reward per episode:  4962.1363364824
# sum of reward per episode:  4785.950167119396
# sum of reward per episode:  4755.08232845175
# sum of reward per episode:  4999.209293626522
# sum of reward per episode:  4890.260617020525
# Epoch 60, Average score: 41.55160969543298
# Std score: 3.0251228552193954
# Epoch loss:  -4922.380816459656
# Epoch loss:  -4923.434232711792
# Epoch loss:  -4927.711299061775
# Epoch loss:  -4935.454824090004
# Epoch loss:  -4939.301205039024
# sum of reward per episode:  4940.135619879007
# sum of reward per episode:  4926.020015447065
# sum of reward per episode:  4760.33733138121
# sum of reward per episode:  4669.718573010311
# sum of reward per episode:  4904.130648577253
# Epoch 65, Average score: 41.24183316279719
# Std score: 3.1158505193158477
# Epoch loss:  -4941.095784306526
# Epoch loss:  -4943.324122428894
# Epoch loss:  -4951.08491396904
# Epoch loss:  -4954.643162250519
# Epoch loss:  -4954.605991363525
# sum of reward per episode:  4851.149393350319
# sum of reward per episode:  4617.536007339849
# sum of reward per episode:  4844.498069590828
# sum of reward per episode:  5048.608628248681
# sum of reward per episode:  4865.058545356195
# Epoch 70, Average score: 41.28453646283238
# Std score: 3.359004046561912
# Epoch loss:  -4963.104048132896
# Epoch loss:  -4963.612745523453
# Epoch loss:  -4968.527627110481
# Epoch loss:  -4968.461811065674
# Epoch loss:  -4972.347685456276
# sum of reward per episode:  4892.841453006299
# sum of reward per episode:  4835.344292809175
# sum of reward per episode:  4970.552643041796
# sum of reward per episode:  5017.43379707237
# sum of reward per episode:  4935.797902051488
# Epoch 75, Average score: 41.96937466887773
# Std score: 2.761849666605821
# Epoch loss:  -4973.265173196793
# Epoch loss:  -4978.336653351784
# Epoch loss:  -4982.324561953545
# Epoch loss:  -4987.826757311821
# Epoch loss:  -4988.544623851776
# sum of reward per episode:  5203.440216901237
# sum of reward per episode:  5131.111057291641
# sum of reward per episode:  5103.791119585824
# sum of reward per episode:  4865.433427182887
# sum of reward per episode:  4859.9002708534
# Epoch 80, Average score: 42.793697871581465
# Std score: 3.4056495276045764
# Epoch loss:  -4989.854048490524
# Epoch loss:  -4997.177678823471
# Epoch loss:  -4997.103495359421
# Epoch loss:  -4999.526918053627
# Epoch loss:  -5003.485846161842
# sum of reward per episode:  4800.057185148377
# sum of reward per episode:  4638.136197718943
# sum of reward per episode:  4936.009968305456
# sum of reward per episode:  4942.789650893042
# sum of reward per episode:  4939.201842010574
# Epoch 85, Average score: 41.33180795251698
# Std score: 3.2188467113282213
# Epoch loss:  -5006.46505856514
# Epoch loss:  -5009.978723526001
# Epoch loss:  -5009.092436552048
# Epoch loss:  -5010.313718318939
# Epoch loss:  -5012.650550961494
# sum of reward per episode:  4957.941699213371
# sum of reward per episode:  4917.780680166717
# sum of reward per episode:  5221.264773569707
# sum of reward per episode:  4928.5179183652035
# sum of reward per episode:  5006.240953265085
# Epoch 90, Average score: 42.581167600798715
# Std score: 3.1568081986210252
# Epoch loss:  -5020.468448758125
# Epoch loss:  -5019.626743674278
# Epoch loss:  -5023.329974889755
# Epoch loss:  -5026.021969079971
# Epoch loss:  -5029.987167358398
# sum of reward per episode:  4753.876385552233
# sum of reward per episode:  4893.985050637101
# sum of reward per episode:  5018.04768196007
# sum of reward per episode:  4872.78741050518
# sum of reward per episode:  4698.643814299658
# Epoch 95, Average score: 41.301434647076036
# Std score: 3.1595163345728317
# Epoch loss:  -5034.101708173752
# Epoch loss:  -5037.298762321472
# Epoch loss:  -5037.178410768509
# Epoch loss:  -5039.9023278951645
# Model saved to trained_mle_model_halfcheetah-medium-v2.pth
#
# Mean of the last 10 Average Scores for halfcheetah-medium-v2: 41.69743183665007
# Mean of the last 10 Std Scores for halfcheetah-medium-v2: 3.0957079462168395
# Training on dataset: halfcheetah-medium-expert-v2
# load datafile: 100%|██████████| 9/9 [00:04<00:00,  2.19it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/halfcheetah_medium_expert-v2.hdf5
# Epoch loss:  4623.219692390412
# sum of reward per episode:  9478.283360700845
# sum of reward per episode:  9751.66232144222
# sum of reward per episode:  10122.17610736855
# sum of reward per episode:  9795.423513339781
# sum of reward per episode:  10113.957259857692
# Epoch 0, Average score: 81.61364007639565
# Std score: 4.211718164809337
# Epoch loss:  -6707.300938606262
# Epoch loss:  -7519.1263118982315
# Epoch loss:  -7870.661458849907
# Epoch loss:  -8103.489976286888
# Epoch loss:  -8274.59080696106
# sum of reward per episode:  11145.073618588669
# sum of reward per episode:  10985.85725176477
# sum of reward per episode:  10996.933424176126
# sum of reward per episode:  11046.982969266754
# sum of reward per episode:  10989.798988872875
# Epoch 5, Average score: 91.12319883879049
# Std score: 2.7419746672038303
# Epoch loss:  -8396.160711288452
# Epoch loss:  -8506.720096230507
# Epoch loss:  -8589.141565203667
# Epoch loss:  -8663.85171532631
# Epoch loss:  -8730.658005952835
# sum of reward per episode:  11144.173590475744
# sum of reward per episode:  11087.646124350958
# sum of reward per episode:  11325.41994769708
# sum of reward per episode:  11147.926724169838
# sum of reward per episode:  11256.926957438438
# Epoch 10, Average score: 92.40783129472499
# Std score: 2.9508964420948196
# Epoch loss:  -8782.688828110695
# Epoch loss:  -8827.902889966965
# Epoch loss:  -8871.444850564003
# Epoch loss:  -8916.15978205204
# Epoch loss:  -8948.883517503738
# sum of reward per episode:  11119.94969536042
# sum of reward per episode:  11058.734549886993
# sum of reward per episode:  10945.388347832293
# sum of reward per episode:  10730.16799482387
# sum of reward per episode:  10710.195435779404
# Epoch 15, Average score: 90.1563014122476
# Std score: 3.602971589870903
# Epoch loss:  -8987.418797254562
# Epoch loss:  -9013.998656272888
# Epoch loss:  -9041.353079676628
# Epoch loss:  -9066.878214001656
# Epoch loss:  -9089.505700230598
# sum of reward per episode:  10995.279896891363
# sum of reward per episode:  11140.907455733557
# sum of reward per episode:  11199.642922244086
# sum of reward per episode:  11111.02527309298
# sum of reward per episode:  11095.478021259345
# Epoch 20, Average score: 91.73162714736645
# Std score: 2.7952880914709484
# Epoch loss:  -9107.590230464935
# Epoch loss:  -9132.24742925167
# Epoch loss:  -9149.227621674538
# Epoch loss:  -9169.356490373611
# Epoch loss:  -9183.718417286873
# sum of reward per episode:  11317.224610696328
# sum of reward per episode:  11438.04738304636
# sum of reward per episode:  11326.81066878342
# sum of reward per episode:  11361.209124037143
# sum of reward per episode:  11268.759671078604
# Epoch 25, Average score: 93.61596227108633
# Std score: 2.7095563004672174
# Epoch loss:  -9202.678009390831
# Epoch loss:  -9217.997501015663
# Epoch loss:  -9226.687917351723
# Epoch loss:  -9241.80533027649
# Epoch loss:  -9256.224583625793
# sum of reward per episode:  10914.135819197927
# sum of reward per episode:  11060.084671999339
# sum of reward per episode:  10908.784142160204
# sum of reward per episode:  10899.72687502128
# sum of reward per episode:  10811.891341464372
# Epoch 30, Average score: 90.204930314456
# Std score: 2.899874043324076
# Epoch loss:  -9264.80667412281
# Epoch loss:  -9280.379163265228
# Epoch loss:  -9290.949849843979
# Epoch loss:  -9303.152624368668
# Epoch loss:  -9310.932931661606
# sum of reward per episode:  11271.113459760978
# sum of reward per episode:  11411.870699526455
# sum of reward per episode:  11303.88768642975
# sum of reward per episode:  11356.560934083986
# sum of reward per episode:  11051.540474192196
# Epoch 35, Average score: 93.10517107774358
# Std score: 3.250376101460828
# Epoch loss:  -9319.277843594551
# Epoch loss:  -9331.700415372849
# Epoch loss:  -9342.911183595657
# Epoch loss:  -9350.03623867035
# Epoch loss:  -9353.682469725609
# sum of reward per episode:  11253.716332789045
# sum of reward per episode:  10908.669102447275
# sum of reward per episode:  11243.462313705519
# sum of reward per episode:  11346.995514186641
# sum of reward per episode:  11189.613940287145
# Epoch 40, Average score: 92.3761988216193
# Std score: 3.4552467911673204
# Epoch loss:  -9363.192262172699
# Epoch loss:  -9373.018989801407
# Epoch loss:  -9378.305213451385
# Epoch loss:  -9385.525344848633
# Epoch loss:  -9397.527415633202
# sum of reward per episode:  11322.148296118958
# sum of reward per episode:  11259.45256128057
# sum of reward per episode:  11421.300043600037
# sum of reward per episode:  11419.48344809377
# sum of reward per episode:  11273.399334071026
# Epoch 45, Average score: 93.58975600448495
# Std score: 2.816714509752133
# Epoch loss:  -9398.8186814785
# Epoch loss:  -9409.117221713066
# Epoch loss:  -9412.58969259262
# Epoch loss:  -9421.894414901733
# Epoch loss:  -9429.141378045082
# sum of reward per episode:  11121.366122046658
# sum of reward per episode:  11247.639796747311
# sum of reward per episode:  11328.449600554874
# sum of reward per episode:  11224.889132699062
# sum of reward per episode:  11297.26730935568
# Epoch 50, Average score: 92.82267608793565
# Std score: 2.830682857486906
# Epoch loss:  -9429.990057587624
# Epoch loss:  -9436.64883685112
# Epoch loss:  -9442.030786275864
# Epoch loss:  -9445.083034873009
# Epoch loss:  -9455.363958001137
# sum of reward per episode:  11275.029818158911
# sum of reward per episode:  11288.633375170524
# sum of reward per episode:  11164.0799460612
# sum of reward per episode:  11214.332406674135
# sum of reward per episode:  11261.954295867807
# Epoch 55, Average score: 92.79757436442429
# Std score: 2.625745446946525
# Epoch loss:  -9453.654078483582
# Epoch loss:  -9460.331884622574
# Epoch loss:  -9469.677579760551
# Epoch loss:  -9469.460354924202
# Epoch loss:  -9472.05659878254
# sum of reward per episode:  10838.762033596435
# sum of reward per episode:  10947.575668448948
# sum of reward per episode:  11022.725476436779
# sum of reward per episode:  11046.452589490822
# sum of reward per episode:  11006.307638618893
# Epoch 60, Average score: 90.63537204672615
# Std score: 2.8556294910114777
# Epoch loss:  -9485.663486719131
# Epoch loss:  -9483.543281912804
# Epoch loss:  -9493.631638288498
# Epoch loss:  -9493.706279754639
# Epoch loss:  -9497.24857878685
# sum of reward per episode:  8438.202398537383
# sum of reward per episode:  11111.508014071538
# sum of reward per episode:  10755.46554810194
# sum of reward per episode:  10890.01704791115
# sum of reward per episode:  10902.088521658115
# Epoch 65, Average score: 86.1818850905131
# Std score: 10.288466343756278
# Epoch loss:  -9504.516471266747
# Epoch loss:  -9505.591044902802
# Epoch loss:  -9506.77704334259
# Epoch loss:  -9512.045508503914
# Epoch loss:  -9513.995598554611
# sum of reward per episode:  11270.106844210164
# sum of reward per episode:  11264.910713589743
# sum of reward per episode:  11402.223451907555
# sum of reward per episode:  11392.766799176905
# sum of reward per episode:  11235.210890188106
# Epoch 70, Average score: 93.37942478882364
# Std score: 2.8208829286111214
# Epoch loss:  -9518.382818341255
# Epoch loss:  -9523.485625505447
# Epoch loss:  -9525.435457229614
# Epoch loss:  -9525.405896782875
# Epoch loss:  -9532.042645931244
# sum of reward per episode:  11093.826091568488
# sum of reward per episode:  11014.168127300132
# sum of reward per episode:  10849.059546583396
# sum of reward per episode:  10953.669843958603
# sum of reward per episode:  10982.595313082791
# Epoch 75, Average score: 90.68610915816159
# Std score: 2.900718134841306
# Epoch loss:  -9531.215663075447
# Epoch loss:  -9540.164830446243
# Epoch loss:  -9540.013700842857
# Epoch loss:  -9544.632821679115
# Epoch loss:  -9546.638222455978
# sum of reward per episode:  11207.41746745607
# sum of reward per episode:  10981.066992296202
# sum of reward per episode:  11225.310427107628
# sum of reward per episode:  11428.165538611269
# sum of reward per episode:  11380.164737812525
# Epoch 80, Average score: 92.82672468343259
# Std score: 3.521496682620768
# Epoch loss:  -9548.938279151917
# Epoch loss:  -9552.504225850105
# Epoch loss:  -9546.788149952888
# Epoch loss:  -9558.483946561813
# Epoch loss:  -9559.886860251427
# sum of reward per episode:  11348.518393232753
# sum of reward per episode:  11297.274177940415
# sum of reward per episode:  11231.071131484012
# sum of reward per episode:  11426.091492714047
# sum of reward per episode:  11248.127531083568
# Epoch 85, Average score: 93.35665270849984
# Std score: 2.828348705726761
# Epoch loss:  -9560.163091778755
# Epoch loss:  -9564.304614663124
# Epoch loss:  -9566.779380202293
# Epoch loss:  -9568.078228116035
# Epoch loss:  -9570.551359653473
# sum of reward per episode:  11217.025164779008
# sum of reward per episode:  11127.8834016087
# sum of reward per episode:  11086.355329512722
# sum of reward per episode:  11050.974352414065
# sum of reward per episode:  11072.216590549107
# Epoch 90, Average score: 91.75115367966734
# Std score: 2.729724540265912
# Epoch loss:  -9576.42701125145
# Epoch loss:  -9577.494529008865
# Epoch loss:  -9581.941316604614
# Epoch loss:  -9578.403710007668
# Epoch loss:  -9585.362805366516
# sum of reward per episode:  11101.596183678263
# sum of reward per episode:  11030.32595175116
# sum of reward per episode:  11374.175960101273
# sum of reward per episode:  11153.85708539631
# sum of reward per episode:  11258.17210071598
# Epoch 95, Average score: 92.33700498983538
# Std score: 3.229875631325015
# Epoch loss:  -9587.437896728516
# Epoch loss:  -9589.379977107048
# Epoch loss:  -9586.716400027275
# Epoch loss:  -9593.986155629158
# Model saved to trained_mle_model_halfcheetah-medium-expert-v2.pth
#
# Mean of the last 10 Average Scores for halfcheetah-medium-expert-v2: 91.67745775980195
# Mean of the last 10 Std Scores for halfcheetah-medium-expert-v2: 3.663157076259207
# Training on dataset: hopper-medium-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/hopper_medium-v2.hdf5 to /root/.d4rl/datasets/hopper_medium-v2.hdf5
# load datafile: 100%|██████████| 21/21 [00:01<00:00, 16.02it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/hopper_medium-v2.hdf5
# Epoch loss:  3250.2113173007965
# sum of reward per episode:  943.2785842215575
# sum of reward per episode:  862.1801092866906
# sum of reward per episode:  874.7981466290855
# sum of reward per episode:  937.1299591524181
# sum of reward per episode:  922.6269513349974
# Epoch 0, Average score: 28.522182582910794
# Std score: 1.6427779157346407
# Epoch loss:  363.47618436440825
# Epoch loss:  -196.68747121933848
# Epoch loss:  -301.2650068094954
# Epoch loss:  -353.27032654266804
# Epoch loss:  -387.6120440280065
# sum of reward per episode:  1067.2307671936994
# sum of reward per episode:  1023.1836407514791
# sum of reward per episode:  425.4493301546073
# sum of reward per episode:  1118.3260492123206
# sum of reward per episode:  366.66879958525067
# Epoch 5, Average score: 25.208965894505486
# Std score: 10.819279391862175
# Epoch loss:  -414.456972964108
# Epoch loss:  -439.7383145466447
# Epoch loss:  -455.0350485416129
# Epoch loss:  -469.66356715746224
# Epoch loss:  -484.9311148840934
# sum of reward per episode:  1052.5281348155956
# sum of reward per episode:  1060.3931700230512
# sum of reward per episode:  1050.4612770501565
# sum of reward per episode:  1039.658841477082
# sum of reward per episode:  1047.3854622908973
# Epoch 10, Average score: 32.88781387609568
# Std score: 0.8305370312458377
# Epoch loss:  -495.844683714211
# Epoch loss:  -504.56507935002446
# Epoch loss:  -513.0174398049712
# Epoch loss:  -524.7802560534328
# Epoch loss:  -530.390943126753
# sum of reward per episode:  1389.6737531843592
# sum of reward per episode:  1286.8791297162404
# sum of reward per episode:  1417.3592339586453
# sum of reward per episode:  1326.8031903715223
# sum of reward per episode:  1355.3419419975073
# Epoch 15, Average score: 42.263118651028314
# Std score: 2.0326949082363943
# Epoch loss:  -536.737563373521
# Epoch loss:  -541.9943851400167
# Epoch loss:  -547.8912779577076
# Epoch loss:  -553.9708850700408
# Epoch loss:  -560.6769410539418
# sum of reward per episode:  1338.0406825834136
# sum of reward per episode:  1289.265204672079
# sum of reward per episode:  1286.8576298395303
# sum of reward per episode:  1272.0412062847038
# sum of reward per episode:  1297.1704776139525
# Epoch 20, Average score: 40.46452872395893
# Std score: 1.3057338636795666
# Epoch loss:  -562.2726325392723
# Epoch loss:  -567.9681575689465
# Epoch loss:  -572.2513811327517
# Epoch loss:  -572.7292793430388
# Epoch loss:  -578.8771995306015
# sum of reward per episode:  1431.3740750731522
# sum of reward per episode:  1395.3198023645566
# sum of reward per episode:  1463.2684729634884
# sum of reward per episode:  1452.027686286304
# sum of reward per episode:  1454.9542445855077
# Epoch 25, Average score: 44.849553934079864
# Std score: 1.372824968267462
# Epoch loss:  -582.0127446288243
# Epoch loss:  -583.584060607478
# Epoch loss:  -588.7887789011002
# Epoch loss:  -589.53378806822
# Epoch loss:  -593.8769550230354
# sum of reward per episode:  1390.6202793127495
# sum of reward per episode:  1336.8903900515315
# sum of reward per episode:  1403.9611480202548
# sum of reward per episode:  1255.9753145105558
# sum of reward per episode:  1571.6799291315745
# Epoch 30, Average score: 43.388119386253194
# Std score: 3.815124419493531
# Epoch loss:  -595.4114322345704
# Epoch loss:  -598.2762203626335
# Epoch loss:  -601.0427909903228
# Epoch loss:  -604.1170799806714
# Epoch loss:  -603.3063599169254
# sum of reward per episode:  1299.977723061004
# sum of reward per episode:  1439.475944770907
# sum of reward per episode:  1296.4627082955988
# sum of reward per episode:  1285.8286681749646
# sum of reward per episode:  1396.1417941007687
# Epoch 35, Average score: 41.905649801830045
# Std score: 2.537547858277073
# Epoch loss:  -607.1880543380976
# Epoch loss:  -608.7036762814969
# Epoch loss:  -611.6123006921262
# Epoch loss:  -612.9383995756507
# Epoch loss:  -615.4858151748776
# sum of reward per episode:  1247.5334223489958
# sum of reward per episode:  1218.3512129014532
# sum of reward per episode:  1402.082150570313
# sum of reward per episode:  1283.6918607876003
# sum of reward per episode:  951.548558239178
# Epoch 40, Average score: 38.128320088728465
# Std score: 5.1810248562433285
# Epoch loss:  -617.016413860023
# Epoch loss:  -619.4140992797911
# Epoch loss:  -619.7828174550086
# Epoch loss:  -620.3514057546854
# Epoch loss:  -623.6826678439975
# sum of reward per episode:  1532.0121671126578
# sum of reward per episode:  1487.8254530964355
# sum of reward per episode:  1511.4922408003295
# sum of reward per episode:  1547.4997619541377
# sum of reward per episode:  1446.9487735402427
# Epoch 45, Average score: 46.87030556848412
# Std score: 1.7085914455930127
# Epoch loss:  -624.5975360311568
# Epoch loss:  -626.3971416726708
# Epoch loss:  -628.545294187963
# Epoch loss:  -629.2452735900879
# Epoch loss:  -629.5388656128198
# sum of reward per episode:  1360.9434508934523
# sum of reward per episode:  1720.304858276342
# sum of reward per episode:  1369.2278994467717
# sum of reward per episode:  1335.5886983936082
# sum of reward per episode:  1684.5307110694566
# Epoch 50, Average score: 46.531196320000845
# Std score: 5.871227087616347
# Epoch loss:  -630.1768610402942
# Epoch loss:  -631.5677669905126
# Epoch loss:  -632.0813469476998
# Epoch loss:  -634.3819144256413
# Epoch loss:  -635.9463448859751
# sum of reward per episode:  1242.6542458805088
# sum of reward per episode:  1374.1896281102
# sum of reward per episode:  1257.14459232754
# sum of reward per episode:  1283.1565473065334
# sum of reward per episode:  1265.0498542378236
# Epoch 55, Average score: 40.08856329810497
# Std score: 2.0590578710941987
# Epoch loss:  -636.6324314288795
# Epoch loss:  -636.8723928444088
# Epoch loss:  -638.638651702553
# Epoch loss:  -637.6427520960569
# Epoch loss:  -642.5392624810338
# sum of reward per episode:  1528.762141284913
# sum of reward per episode:  1380.5285700924446
# sum of reward per episode:  1901.4491495372622
# sum of reward per episode:  1314.4324209758822
# sum of reward per episode:  1406.8384591355314
# Epoch 60, Average score: 46.908604576391724
# Std score: 7.055881373003553
# Epoch loss:  -639.730938559398
# Epoch loss:  -642.9166602902114
# Epoch loss:  -642.5929020047188
# Epoch loss:  -646.3711062297225
# Epoch loss:  -646.1524182856083
# sum of reward per episode:  1301.9305884225175
# sum of reward per episode:  1215.3722570841765
# sum of reward per episode:  1245.2376425320117
# sum of reward per episode:  1189.275481140652
# sum of reward per episode:  1290.484170573678
# Epoch 65, Average score: 38.98307408938053
# Std score: 1.943256205776032
# Epoch loss:  -646.394499219954
# Epoch loss:  -647.7656432650983
# Epoch loss:  -648.0774474591017
# Epoch loss:  -648.0080814789981
# Epoch loss:  -649.0601528771222
# sum of reward per episode:  1363.209323151643
# sum of reward per episode:  1454.9130867520053
# sum of reward per episode:  1363.5372770625404
# sum of reward per episode:  1363.146537552154
# sum of reward per episode:  1377.706965867346
# Epoch 70, Average score: 43.163119802838146
# Std score: 1.718116771448918
# Epoch loss:  -650.6603231355548
# Epoch loss:  -652.3836598414928
# Epoch loss:  -651.7878966368735
# Epoch loss:  -654.2143932804465
# Epoch loss:  -653.9267186671495
# sum of reward per episode:  1314.1790900443546
# sum of reward per episode:  1306.2677237120297
# sum of reward per episode:  1341.2015121809327
# sum of reward per episode:  1382.8498510018403
# sum of reward per episode:  1344.1596054169295
# Epoch 75, Average score: 41.726031386210636
# Std score: 1.4512034781000274
# Epoch loss:  -653.8480187822133
# Epoch loss:  -655.1398216616362
# Epoch loss:  -655.5561965256929
# Epoch loss:  -657.5495144613087
# Epoch loss:  -656.2485073059797
# sum of reward per episode:  1505.1924849985908
# sum of reward per episode:  1485.3395977314917
# sum of reward per episode:  1492.795418164918
# sum of reward per episode:  1484.449242153034
# sum of reward per episode:  1479.5399115538278
# Epoch 80, Average score: 46.388142417391165
# Std score: 0.8974094775886645
# Epoch loss:  -657.0253690732643
# Epoch loss:  -658.8499420899898
# Epoch loss:  -659.1498169787228
# Epoch loss:  -658.316956769675
# Epoch loss:  -661.5959832370281
# sum of reward per episode:  1374.1878246180527
# sum of reward per episode:  1374.1866296341282
# sum of reward per episode:  1390.531638247334
# sum of reward per episode:  1447.7434532372208
# sum of reward per episode:  1338.0439517693674
# Epoch 85, Average score: 43.17651822767598
# Std score: 1.722691041542263
# Epoch loss:  -659.4363985396922
# Epoch loss:  -661.7660368680954
# Epoch loss:  -662.2947926521301
# Epoch loss:  -663.2507655397058
# Epoch loss:  -662.2565748728812
# sum of reward per episode:  1418.1797337265766
# sum of reward per episode:  1451.6690900622154
# sum of reward per episode:  1441.7467776315405
# sum of reward per episode:  1464.2686653931166
# sum of reward per episode:  1927.03367189167
# Epoch 90, Average score: 47.95874070282865
# Std score: 6.57810387818792
# Epoch loss:  -664.4676345512271
# Epoch loss:  -664.2184831686318
# Epoch loss:  -666.0679142326117
# Epoch loss:  -665.6112240701914
# Epoch loss:  -666.7519127689302
# sum of reward per episode:  1267.891180939706
# sum of reward per episode:  1627.625724940526
# sum of reward per episode:  1315.3614366492898
# sum of reward per episode:  1469.895162852398
# sum of reward per episode:  1435.542102696391
# Epoch 95, Average score: 44.35407455529442
# Std score: 4.506357370518613
# Epoch loss:  -666.8185540027916
# Epoch loss:  -668.4368955418468
# Epoch loss:  -666.9124455675483
# Epoch loss:  -670.0988370999694
# Model saved to trained_mle_model_hopper-medium-v2.pth
#
# Mean of the last 10 Average Scores for hopper-medium-v2: 43.92780653761171
# Mean of the last 10 Std Scores for hopper-medium-v2: 3.380330455487654
# Training on dataset: hopper-medium-expert-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/hopper_medium_expert-v2.hdf5 to /root/.d4rl/datasets/hopper_medium_expert-v2.hdf5
# load datafile: 100%|██████████| 9/9 [00:02<00:00,  3.22it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/hopper_medium_expert-v2.hdf5
# Epoch loss:  4197.549937129021
# sum of reward per episode:  844.6987934342387
# sum of reward per episode:  2114.9572290531387
# sum of reward per episode:  995.1607492942452
# sum of reward per episode:  857.5759945575932
# sum of reward per episode:  825.4897166548847
# Epoch 0, Average score: 35.268806283251976
# Std score: 15.903513422461888
# Epoch loss:  497.29295378550887
# Epoch loss:  138.58018448250368
# Epoch loss:  -44.52747593354434
# Epoch loss:  -162.59378036903217
# Epoch loss:  -249.32758849766105
# sum of reward per episode:  1273.4908150042954
# sum of reward per episode:  1347.3752307565294
# sum of reward per episode:  1353.0463884666904
# sum of reward per episode:  1261.977553330939
# sum of reward per episode:  1255.2067586967084
# Epoch 5, Average score: 40.511979169288516
# Std score: 1.940696228326714
# Epoch loss:  -316.09651428926736
# Epoch loss:  -373.6149852084927
# Epoch loss:  -415.512492492795
# Epoch loss:  -455.53495991928503
# Epoch loss:  -493.0785194262862
# sum of reward per episode:  372.4424817358554
# sum of reward per episode:  373.279865874756
# sum of reward per episode:  364.86359874982
# sum of reward per episode:  372.9492454404895
# sum of reward per episode:  367.28919672491827
# Epoch 10, Average score: 11.996574238198361
# Std score: 0.728448901634322
# Epoch loss:  -519.2276974045672
# Epoch loss:  -546.5170771596022
# Epoch loss:  -564.6761611658148
# Epoch loss:  -588.8450825382024
# Epoch loss:  -606.7035598075017
# sum of reward per episode:  2799.3158265360444
# sum of reward per episode:  2184.725734733824
# sum of reward per episode:  1908.4183231967233
# sum of reward per episode:  1653.5721336832544
# sum of reward per episode:  1812.2600729124756
# Epoch 15, Average score: 64.27667070105132
# Std score: 12.997500107164257
# Epoch loss:  -627.3976673147408
# Epoch loss:  -640.8850432094187
# Epoch loss:  -652.4997264472768
# Epoch loss:  -664.1607836605981
# Epoch loss:  -675.8659061687067
# sum of reward per episode:  2761.8802226089865
# sum of reward per episode:  1538.415937612067
# sum of reward per episode:  2486.7985133556504
# sum of reward per episode:  2857.4659638111557
# sum of reward per episode:  2810.6368070229037
# Epoch 20, Average score: 77.16257494184497
# Std score: 15.783454027733654
# Epoch loss:  -690.2138731470332
# Epoch loss:  -698.491633489728
# Epoch loss:  -709.7159073171206
# Epoch loss:  -721.2040815693326
# Epoch loss:  -727.0921517126262
# sum of reward per episode:  1611.526841098871
# sum of reward per episode:  1225.1204058514381
# sum of reward per episode:  1056.4426983006956
# sum of reward per episode:  1068.4824332381206
# sum of reward per episode:  2407.226728426824
# Epoch 25, Average score: 45.905636328555595
# Std score: 16.233179205226342
# Epoch loss:  -733.3704787995666
# Epoch loss:  -745.3539617722854
# Epoch loss:  -750.1833490673453
# Epoch loss:  -758.6444586114958
# Epoch loss:  -762.2830302398652
# sum of reward per episode:  3536.913143315067
# sum of reward per episode:  3632.045446615091
# sum of reward per episode:  3514.3730147103774
# sum of reward per episode:  3531.645135756049
# sum of reward per episode:  3624.6928842056327
# Epoch 30, Average score: 110.25123714129495
# Std score: 2.157945433695451
# Epoch loss:  -769.6709147160873
# Epoch loss:  -775.8473888961598
# Epoch loss:  -781.6931807706133
# Epoch loss:  -789.4069534791633
# Epoch loss:  -792.6555963372812
# sum of reward per episode:  2176.759121217412
# sum of reward per episode:  3533.3623578700194
# sum of reward per episode:  3514.361035348923
# sum of reward per episode:  2158.73757274966
# sum of reward per episode:  1860.8170441778743
# Epoch 35, Average score: 82.0101531366279
# Std score: 22.845870700852583
# Epoch loss:  -799.1465851799585
# Epoch loss:  -801.1920867497101
# Epoch loss:  -808.121894620359
# Epoch loss:  -814.9412405798212
# Epoch loss:  -817.5039141476154
# sum of reward per episode:  3499.706201383611
# sum of reward per episode:  3617.3659867462693
# sum of reward per episode:  2731.247093839103
# sum of reward per episode:  3523.7192465911066
# sum of reward per episode:  3518.2325085052353
# Epoch 40, Average score: 104.41699227859267
# Std score: 10.638782084656645
# Epoch loss:  -822.1420349981636
# Epoch loss:  -825.6789294350892
# Epoch loss:  -827.8529374264181
# Epoch loss:  -832.9813975356519
# Epoch loss:  -837.5026580663398
# sum of reward per episode:  1339.6773003304797
# sum of reward per episode:  1323.144201926669
# sum of reward per episode:  1302.9025874780893
# sum of reward per episode:  1291.579381651404
# sum of reward per episode:  1314.8732026252871
# Epoch 45, Average score: 41.01023159792381
# Std score: 1.1312313051987015
# Epoch loss:  -839.4980624327436
# Epoch loss:  -842.3144168294966
# Epoch loss:  -847.075798233971
# Epoch loss:  -849.5317127937451
# Epoch loss:  -850.3920519566163
# sum of reward per episode:  1302.9823687559856
# sum of reward per episode:  1125.1110214211135
# sum of reward per episode:  1024.092555173064
# sum of reward per episode:  1290.5304163123426
# sum of reward per episode:  1299.935716001764
# Epoch 50, Average score: 37.756196678901375
# Std score: 4.125549434841907
# Epoch loss:  -855.885899586603
# Epoch loss:  -857.837955233641
# Epoch loss:  -863.6802330184728
# Epoch loss:  -866.2199271665886
# Epoch loss:  -870.161674618721
# sum of reward per episode:  974.7239293174216
# sum of reward per episode:  1030.0250959599834
# sum of reward per episode:  981.0472684935947
# sum of reward per episode:  1045.7166165560513
# sum of reward per episode:  979.2106115415534
# Epoch 55, Average score: 31.41478859765935
# Std score: 1.534243287725696
# Epoch loss:  -869.0915184775367
# Epoch loss:  -874.5602656397969
# Epoch loss:  -876.5128499958664
# Epoch loss:  -878.1588351354003
# Epoch loss:  -880.6397276585922
# sum of reward per episode:  3583.31000003597
# sum of reward per episode:  3530.8284908557093
# sum of reward per episode:  3662.482946722317
# sum of reward per episode:  2723.7449787952055
# sum of reward per episode:  3499.142520663405
# Epoch 60, Average score: 105.08828109795265
# Std score: 11.148648794609208
# Epoch loss:  -884.7105359937996
# Epoch loss:  -887.0556012485176
# Epoch loss:  -887.8110077800229
# Epoch loss:  -891.1337681803852
# Epoch loss:  -893.0933670746163
# sum of reward per episode:  961.5471437313295
# sum of reward per episode:  861.6546081807357
# sum of reward per episode:  936.9594986932428
# sum of reward per episode:  963.5538216895943
# sum of reward per episode:  927.7496778135887
# Epoch 65, Average score: 29.207071342718237
# Std score: 1.759769246187226
# Epoch loss:  -895.7805748675019
# Epoch loss:  -897.3528727721423
# Epoch loss:  -898.3545492431149
# Epoch loss:  -901.2706123646349
# Epoch loss:  -900.3516395185143
# sum of reward per episode:  1338.3364569875916
# sum of reward per episode:  1333.0907762673266
# sum of reward per episode:  1086.399610905633
# sum of reward per episode:  1207.6253393582913
# sum of reward per episode:  1324.984256908241
# Epoch 70, Average score: 39.278881317876206
# Std score: 3.651034670830399
# Epoch loss:  -905.4812988303602
# Epoch loss:  -906.778108837083
# Epoch loss:  -908.0367243420333
# Epoch loss:  -908.2061173627153
# Epoch loss:  -911.0684546018019
# sum of reward per episode:  1049.419935972292
# sum of reward per episode:  1211.3691891183169
# sum of reward per episode:  1320.757783289272
# sum of reward per episode:  1366.2626663820743
# sum of reward per episode:  1393.8954195077372
# Epoch 75, Average score: 39.593936870729365
# Std score: 4.4917362106069305
# Epoch loss:  -914.1478719692677
# Epoch loss:  -914.9621739201248
# Epoch loss:  -915.3093299837783
# Epoch loss:  -920.2566655017436
# Epoch loss:  -920.9343722127378
# sum of reward per episode:  1340.7506850250636
# sum of reward per episode:  1998.6265990950653
# sum of reward per episode:  1318.9074944463637
# sum of reward per episode:  1688.4298299242485
# sum of reward per episode:  1372.1575773414495
# Epoch 80, Average score: 48.05690565742209
# Std score: 8.741204130745588
# Epoch loss:  -919.7210411410779
# Epoch loss:  -923.0480772769079
# Epoch loss:  -923.5606340635568
# Epoch loss:  -925.9963501347229
# Epoch loss:  -926.9645225359127
# sum of reward per episode:  2328.905263862617
# sum of reward per episode:  1345.2347538775844
# sum of reward per episode:  1340.1483181750366
# sum of reward per episode:  1361.5409140866723
# sum of reward per episode:  1343.2942964470953
# Epoch 85, Average score: 48.05845031885991
# Std score: 12.686225396693676
# Epoch loss:  -928.2590424381196
# Epoch loss:  -930.9486622698605
# Epoch loss:  -932.1760111646727
# Epoch loss:  -933.5866513038054
# Epoch loss:  -935.2770250998437
# sum of reward per episode:  1987.880851903528
# sum of reward per episode:  1988.8204688963378
# sum of reward per episode:  3509.0669027045456
# sum of reward per episode:  2264.0911680692657
# sum of reward per episode:  1926.7723996889467
# Epoch 90, Average score: 72.3781327467704
# Std score: 19.009479215536484
# Epoch loss:  -934.3629452781752
# Epoch loss:  -937.2772069117054
# Epoch loss:  -938.4572011027485
# Epoch loss:  -939.241813397035
# Epoch loss:  -940.7140765339136
# sum of reward per episode:  3580.2261948126916
# sum of reward per episode:  3492.164555232223
# sum of reward per episode:  3815.6233742069935
# sum of reward per episode:  3607.159934245052
# sum of reward per episode:  3583.520982390196
# Epoch 95, Average score: 111.72009629626041
# Std score: 3.9206665657549022
# Epoch loss:  -943.60165645089
# Epoch loss:  -942.8979499917477
# Epoch loss:  -944.234348135069
# Epoch loss:  -946.307054896839
# Model saved to trained_mle_model_hopper-medium-expert-v2.pth
#
# Mean of the last 10 Average Scores for hopper-medium-expert-v2: 56.255274092515
# Mean of the last 10 Std Scores for hopper-medium-expert-v2: 7.106855695353201
# Training on dataset: walker2d-medium-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/walker2d_medium-v2.hdf5 to /root/.d4rl/datasets/walker2d_medium-v2.hdf5
# load datafile: 100%|██████████| 21/21 [00:02<00:00, 10.23it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/walker2d_medium-v2.hdf5
# Epoch loss:  5970.37741535902
# sum of reward per episode:  3578.649416635125
# sum of reward per episode:  3692.7786594175213
# sum of reward per episode:  3508.7398294679556
# sum of reward per episode:  3653.814075769553
# sum of reward per episode:  3657.7189828469564
# Epoch 0, Average score: 78.78393357158765
# Std score: 1.4074108867633663
# Epoch loss:  -1188.6340806633234
# Epoch loss:  -2981.443869113922
# Epoch loss:  -3258.612922489643
# Epoch loss:  -3387.5158504247665
# Epoch loss:  -3477.2842451334
# sum of reward per episode:  3606.524488369718
# sum of reward per episode:  3763.5158606136347
# sum of reward per episode:  3576.558732924278
# sum of reward per episode:  2526.002548525024
# sum of reward per episode:  3409.304166083454
# Epoch 5, Average score: 73.51326542861113
# Std score: 9.544901804256249
# Epoch loss:  -3552.13177549839
# Epoch loss:  -3605.327137708664
# Epoch loss:  -3658.509500026703
# Epoch loss:  -3695.3171689510345
# Epoch loss:  -3727.493105173111
# sum of reward per episode:  3738.489966090855
# sum of reward per episode:  3520.1751477774483
# sum of reward per episode:  2756.3393462283298
# sum of reward per episode:  3188.51610044715
# sum of reward per episode:  3704.171929152741
# Epoch 10, Average score: 73.62560932441774
# Std score: 7.991055960838789
# Epoch loss:  -3761.799287557602
# Epoch loss:  -3791.687035560608
# Epoch loss:  -3811.0624437332153
# Epoch loss:  -3837.1988246440887
# Epoch loss:  -3860.709241271019
# sum of reward per episode:  3691.0769674191115
# sum of reward per episode:  3701.8511974088324
# sum of reward per episode:  3783.9637942194518
# sum of reward per episode:  2701.27555514622
# sum of reward per episode:  3774.582506073246
# Epoch 15, Average score: 76.87157285292501
# Std score: 9.033173188442214
# Epoch loss:  -3877.8116607666016
# Epoch loss:  -3894.7812390327454
# Epoch loss:  -3914.0148322582245
# Epoch loss:  -3928.1734912395477
# Epoch loss:  -3944.3572417497635
# sum of reward per episode:  3757.2333181407816
# sum of reward per episode:  3751.81512541174
# sum of reward per episode:  3875.9646040180746
# sum of reward per episode:  3642.0052958473457
# sum of reward per episode:  3659.728018303241
# Epoch 20, Average score: 81.37634500172959
# Std score: 1.7853278148176217
# Epoch loss:  -3953.794786453247
# Epoch loss:  -3967.653392791748
# Epoch loss:  -3977.829642891884
# Epoch loss:  -3995.7149291038513
# Epoch loss:  -4003.6719477176666
# sum of reward per episode:  3674.726156172734
# sum of reward per episode:  3748.363031244147
# sum of reward per episode:  2352.5708201881066
# sum of reward per episode:  3765.4615491320187
# sum of reward per episode:  3631.492498509863
# Epoch 25, Average score: 74.77978293438483
# Std score: 11.796404629213365
# Epoch loss:  -4016.4569387435913
# Epoch loss:  -4024.2112904787064
# Epoch loss:  -4033.905808568001
# Epoch loss:  -4040.3388459682465
# Epoch loss:  -4049.786400794983
# sum of reward per episode:  3616.1960206669055
# sum of reward per episode:  3639.6686604861106
# sum of reward per episode:  3560.2572150744386
# sum of reward per episode:  3599.9144000852516
# sum of reward per episode:  1723.8561809248406
# Epoch 30, Average score: 70.28056449852222
# Std score: 16.356598195996874
# Epoch loss:  -4059.114465355873
# Epoch loss:  -4066.396041870117
# Epoch loss:  -4073.9233553409576
# Epoch loss:  -4080.922538995743
# Epoch loss:  -4090.3402708768845
# sum of reward per episode:  3762.9593378189265
# sum of reward per episode:  3525.3598024571816
# sum of reward per episode:  3712.442915962946
# sum of reward per episode:  2484.820505692653
# sum of reward per episode:  2891.4614891806896
# Epoch 35, Average score: 71.31375365230015
# Std score: 10.915368466135785
# Epoch loss:  -4097.550223469734
# Epoch loss:  -4105.027351260185
# Epoch loss:  -4110.321703076363
# Epoch loss:  -4115.358291387558
# Epoch loss:  -4121.581220626831
# sum of reward per episode:  3711.969104948771
# sum of reward per episode:  3644.3071704800645
# sum of reward per episode:  2494.028982206912
# sum of reward per episode:  3726.8170461729374
# sum of reward per episode:  3720.9734564750543
# Epoch 40, Average score: 75.32646425942657
# Std score: 10.501221916219619
# Epoch loss:  -4126.807324409485
# Epoch loss:  -4132.802773237228
# Epoch loss:  -4141.606794476509
# Epoch loss:  -4144.367441415787
# Epoch loss:  -4150.143143773079
# sum of reward per episode:  3702.6450045719916
# sum of reward per episode:  3300.185634313054
# sum of reward per episode:  3749.317037433064
# sum of reward per episode:  3810.284583717335
# sum of reward per episode:  2024.3041296950214
# Epoch 45, Average score: 72.22731221044324
# Std score: 14.578158335306249
# Epoch loss:  -4154.399155974388
# Epoch loss:  -4159.66595184803
# Epoch loss:  -4164.974046945572
# Epoch loss:  -4171.5039612054825
# Epoch loss:  -4175.626581907272
# sum of reward per episode:  3657.246621349529
# sum of reward per episode:  3194.5681280739773
# sum of reward per episode:  3552.7522056513794
# sum of reward per episode:  3666.4320147798567
# sum of reward per episode:  3573.8241371731797
# Epoch 50, Average score: 76.83703797446077
# Std score: 3.734384163134266
# Epoch loss:  -4178.558997392654
# Epoch loss:  -4184.137710809708
# Epoch loss:  -4189.5123525857925
# Epoch loss:  -4193.8351447582245
# Epoch loss:  -4195.533347129822
# sum of reward per episode:  3521.1087893991375
# sum of reward per episode:  3715.0305104859203
# sum of reward per episode:  2802.9645212825776
# sum of reward per episode:  3854.4940140776907
# sum of reward per episode:  3673.3238600508566
# Epoch 55, Average score: 76.49764788587655
# Std score: 8.041121661342373
# Epoch loss:  -4202.907939314842
# Epoch loss:  -4205.194654107094
# Epoch loss:  -4210.065979838371
# Epoch loss:  -4212.810340046883
# Epoch loss:  -4217.152326583862
# sum of reward per episode:  3712.7505520081704
# sum of reward per episode:  3679.4773192373395
# sum of reward per episode:  2431.8025929729156
# sum of reward per episode:  3706.2862295917657
# sum of reward per episode:  3704.3941379320277
# Epoch 60, Average score: 75.05031757563265
# Std score: 11.023812141260759
# Epoch loss:  -4219.752900958061
# Epoch loss:  -4224.417504906654
# Epoch loss:  -4228.403911948204
# Epoch loss:  -4230.575650215149
# Epoch loss:  -4233.745553851128
# sum of reward per episode:  3702.675101099771
# sum of reward per episode:  3674.1706069517936
# sum of reward per episode:  3709.82452450583
# sum of reward per episode:  2276.471242031515
# sum of reward per episode:  3800.830211375951
# Epoch 65, Average score: 74.74213105605581
# Std score: 12.592737750147679
# Epoch loss:  -4235.715083122253
# Epoch loss:  -4241.510495424271
# Epoch loss:  -4243.0915759801865
# Epoch loss:  -4248.6045397520065
# Epoch loss:  -4248.1801998615265
# sum of reward per episode:  2544.513253269841
# sum of reward per episode:  1480.224828709913
# sum of reward per episode:  2364.4952864225907
# sum of reward per episode:  2251.9145626485515
# sum of reward per episode:  3630.217963496858
# Epoch 70, Average score: 53.4267033116441
# Std score: 15.0210789043097
# Epoch loss:  -4255.048412680626
# Epoch loss:  -4257.045607805252
# Epoch loss:  -4257.527984499931
# Epoch loss:  -4260.623322486877
# Epoch loss:  -4266.750352740288
# sum of reward per episode:  2337.8124021154176
# sum of reward per episode:  3726.5911341616675
# sum of reward per episode:  2926.379809518646
# sum of reward per episode:  3714.092302370944
# sum of reward per episode:  3782.780090771136
# Epoch 75, Average score: 71.7956513444594
# Std score: 12.485258536976964
# Epoch loss:  -4266.94263613224
# Epoch loss:  -4271.336376905441
# Epoch loss:  -4272.827879786491
# Epoch loss:  -4274.571443796158
# Epoch loss:  -4279.1447150707245
# sum of reward per episode:  3189.1995514900345
# sum of reward per episode:  3631.8200118666095
# sum of reward per episode:  3786.342394686157
# sum of reward per episode:  3657.4046376429014
# sum of reward per episode:  3292.3434935727205
# Epoch 80, Average score: 76.45490203867975
# Std score: 4.962448187043362
# Epoch loss:  -4282.107199192047
# Epoch loss:  -4282.012354373932
# Epoch loss:  -4286.4138325452805
# Epoch loss:  -4289.336522102356
# Epoch loss:  -4293.190720915794
# sum of reward per episode:  3119.839062347729
# sum of reward per episode:  3682.285701803742
# sum of reward per episode:  2012.0033248116285
# sum of reward per episode:  3700.934593404056
# sum of reward per episode:  3655.5169010220834
# Epoch 85, Average score: 70.41425783531402
# Std score: 14.091701323000422
# Epoch loss:  -4297.311872005463
# Epoch loss:  -4294.853345632553
# Epoch loss:  -4297.848140358925
# Epoch loss:  -4301.606996655464
# Epoch loss:  -4302.805234313011
# sum of reward per episode:  2451.9382839239142
# sum of reward per episode:  3167.6576339277804
# sum of reward per episode:  3748.6401635126876
# sum of reward per episode:  3810.1003609187433
# sum of reward per episode:  3714.6099871796496
# Epoch 90, Average score: 73.56136573013995
# Std score: 11.238186381199476
# Epoch loss:  -4304.769603967667
# Epoch loss:  -4305.697653412819
# Epoch loss:  -4310.028038263321
# Epoch loss:  -4311.429364562035
# Epoch loss:  -4309.605907320976
# sum of reward per episode:  3706.3966332231275
# sum of reward per episode:  3681.190904527652
# sum of reward per episode:  3409.502101685373
# sum of reward per episode:  3666.911294590483
# sum of reward per episode:  3599.9877322813013
# Epoch 95, Average score: 78.66320046796302
# Std score: 2.3078129493989663
# Epoch loss:  -4313.324650645256
# Epoch loss:  -4318.620752811432
# Epoch loss:  -4317.339609622955
# Epoch loss:  -4317.831477403641
# Model saved to trained_mle_model_walker2d-medium-v2.pth
#
# Mean of the last 10 Average Scores for walker2d-medium-v2: 72.7443215220226
# Mean of the last 10 Std Scores for walker2d-medium-v2: 9.549854199781397
# Training on dataset: walker2d-medium-expert-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/walker2d_medium_expert-v2.hdf5 to /root/.d4rl/datasets/walker2d_medium_expert-v2.hdf5
# load datafile: 100%|██████████| 9/9 [00:04<00:00,  2.06it/s]
# Dataset loaded and saved at: /root/.d4rl/datasets/walker2d_medium_expert-v2.hdf5
# Epoch loss:  4655.221911762375
# sum of reward per episode:  4984.479309532255
# sum of reward per episode:  1298.0110714061236
# sum of reward per episode:  4644.530853504025
# sum of reward per episode:  4853.36054302617
# sum of reward per episode:  1542.8745944888879
# Epoch 0, Average score: 75.43608052997878
# Std score: 36.43846627797869
# Epoch loss:  -6565.629292845726
# Epoch loss:  -7237.6089371442795
# Epoch loss:  -7526.2411673069
# Epoch loss:  -7714.967381596565
# Epoch loss:  -7857.464886069298
# sum of reward per episode:  4936.93294152552
# sum of reward per episode:  4952.621421271275
# sum of reward per episode:  4941.124481447961
# sum of reward per episode:  4901.551158402022
# sum of reward per episode:  4907.890222008989
# Epoch 5, Average score: 107.31318026310765
# Std score: 0.3960448798738511
# Epoch loss:  -7976.875969409943
# Epoch loss:  -8054.4795426130295
# Epoch loss:  -8128.470151185989
# Epoch loss:  -8190.927020549774
# Epoch loss:  -8244.319878697395
# sum of reward per episode:  4955.593939794026
# sum of reward per episode:  4961.361548881123
# sum of reward per episode:  4942.195236328017
# sum of reward per episode:  4889.945885203712
# sum of reward per episode:  4959.499913825944
# Epoch 10, Average score: 107.61150832667978
# Std score: 0.5470044470047172
# Epoch loss:  -8294.188090085983
# Epoch loss:  -8337.542106747627
# Epoch loss:  -8369.02215731144
# Epoch loss:  -8408.897373437881
# Epoch loss:  -8434.605829715729
# sum of reward per episode:  4904.0756707863975
# sum of reward per episode:  4873.759476349613
# sum of reward per episode:  4854.8792516356625
# sum of reward per episode:  4876.104607793733
# sum of reward per episode:  4891.725866616182
# Epoch 15, Average score: 106.2694315305512
# Std score: 0.32931137700683405
# Epoch loss:  -8466.280750870705
# Epoch loss:  -8488.28851389885
# Epoch loss:  -8510.38923561573
# Epoch loss:  -8531.535031795502
# Epoch loss:  -8551.800388932228
# sum of reward per episode:  4907.624033417688
# sum of reward per episode:  4877.218594234673
# sum of reward per episode:  4916.995490371856
# sum of reward per episode:  4915.779391659364
# sum of reward per episode:  4923.063210718154
# Epoch 20, Average score: 106.87995599403091
# Std score: 0.31789912060604514
# Epoch loss:  -8571.877009749413
# Epoch loss:  -8592.600856781006
# Epoch loss:  -8608.282556414604
# Epoch loss:  -8622.587684988976
# Epoch loss:  -8637.636668920517
# sum of reward per episode:  4886.188371752098
# sum of reward per episode:  4882.945047126254
# sum of reward per episode:  4917.851616462094
# sum of reward per episode:  4917.2871660542
# sum of reward per episode:  4905.748329707271
# Epoch 25, Average score: 106.74637992485397
# Std score: 0.28938857718160316
# Epoch loss:  -8649.305755853653
# Epoch loss:  -8666.42799282074
# Epoch loss:  -8676.76780807972
# Epoch loss:  -8688.467922091484
# Epoch loss:  -8705.24378323555
# sum of reward per episode:  4948.203548513971
# sum of reward per episode:  4939.376276982266
# sum of reward per episode:  4924.584669388147
# sum of reward per episode:  4956.225313925256
# sum of reward per episode:  4926.768541266135
# Epoch 30, Average score: 107.55296275031255
# Std score: 0.2293345652917453
# Epoch loss:  -8718.330409884453
# Epoch loss:  -8723.728044629097
# Epoch loss:  -8731.546489834785
# Epoch loss:  -8745.063302516937
# Epoch loss:  -8753.624013900757
# sum of reward per episode:  4890.657013553014
# sum of reward per episode:  4910.558842542257
# sum of reward per episode:  4916.3927253819675
# sum of reward per episode:  4895.085857088445
# sum of reward per episode:  4911.425098587289
# Epoch 35, Average score: 106.80780452302592
# Std score: 0.18361488927180888
# Epoch loss:  -8763.009497404099
# Epoch loss:  -8769.243089199066
# Epoch loss:  -8777.492998600006
# Epoch loss:  -8788.000179290771
# Epoch loss:  -8793.725779056549
# sum of reward per episode:  4861.205325263699
# sum of reward per episode:  4923.1234802800955
# sum of reward per episode:  4895.237409095137
# sum of reward per episode:  4926.31685702634
# sum of reward per episode:  4900.508859975493
# Epoch 40, Average score: 106.73057134494299
# Std score: 0.47510635030075676
# Epoch loss:  -8799.444303154945
# Epoch loss:  -8809.555458784103
# Epoch loss:  -8816.848378777504
# Epoch loss:  -8823.334486603737
# Epoch loss:  -8829.536576747894
# sum of reward per episode:  4955.074242026602
# sum of reward per episode:  4883.800922211306
# sum of reward per episode:  4831.112049287614
# sum of reward per episode:  4955.9460361002775
# sum of reward per episode:  4949.464212364874
# Epoch 45, Average score: 107.03120508876907
# Std score: 1.0528453253104353
# Epoch loss:  -8837.250614881516
# Epoch loss:  -8842.755915403366
# Epoch loss:  -8846.727325201035
# Epoch loss:  -8854.325340628624
# Epoch loss:  -8855.668967366219
# sum of reward per episode:  4902.7227649672295
# sum of reward per episode:  4876.759501021717
# sum of reward per episode:  4864.868071441197
# sum of reward per episode:  4855.978276989625
# sum of reward per episode:  4876.69097971257
# Epoch 50, Average score: 106.16693985083703
# Std score: 0.30730589980382944
# Epoch loss:  -8860.44095993042
# Epoch loss:  -8870.117040991783
# Epoch loss:  -8874.926743626595
# Epoch loss:  -8875.749782085419
# Epoch loss:  -8881.363263487816
# sum of reward per episode:  4942.923985915963
# sum of reward per episode:  4929.224527628158
# sum of reward per episode:  4936.0663525166165
# sum of reward per episode:  4922.998776241076
# sum of reward per episode:  2597.3671581842877
# Epoch 55, Average score: 97.2425852315844
# Std score: 20.31444335415281
# Epoch loss:  -8888.52807211876
# Epoch loss:  -8889.100178718567
# Epoch loss:  -8897.702455997467
# Epoch loss:  -8902.54533135891
# Epoch loss:  -8898.066898941994
# sum of reward per episode:  4931.0459518919115
# sum of reward per episode:  4947.060165389558
# sum of reward per episode:  4939.424737780596
# sum of reward per episode:  4932.547092832793
# sum of reward per episode:  4934.8189777864845
# Epoch 60, Average score: 107.50825719675659
# Std score: 0.0904517619092553
# Epoch loss:  -8906.219797492027
# Epoch loss:  -8911.971738696098
# Epoch loss:  -8912.997388243675
# Epoch loss:  -8918.504459738731
# Epoch loss:  -8921.88432085514
# sum of reward per episode:  4890.502472311834
# sum of reward per episode:  4907.070183752003
# sum of reward per episode:  4890.910203465731
# sum of reward per episode:  4899.989468304967
# sum of reward per episode:  4896.1782692990255
# Epoch 65, Average score: 106.63585170790006
# Std score: 0.09890205697989801
# Epoch loss:  -8921.940285205841
# Epoch loss:  -8928.528940439224
# Epoch loss:  -8930.65647494793
# Epoch loss:  -8935.051820993423
# Epoch loss:  -8936.61528635025
# sum of reward per episode:  4902.628692418453
# sum of reward per episode:  4926.604402702187
# sum of reward per episode:  4923.214687925267
# sum of reward per episode:  4931.7549175193635
# sum of reward per episode:  4928.876899814594
# Epoch 70, Average score: 107.19537341385623
# Std score: 0.19057411739540792
# Epoch loss:  -8941.120429515839
# Epoch loss:  -8946.80432331562
# Epoch loss:  -8946.192180156708
# Epoch loss:  -8947.097683668137
# Epoch loss:  -8952.206778407097
# sum of reward per episode:  4835.678743846409
# sum of reward per episode:  4917.5625311398135
# sum of reward per episode:  4904.044002866492
# sum of reward per episode:  4885.882571450626
# sum of reward per episode:  4916.844261827315
# Epoch 75, Average score: 106.52851016220497
# Std score: 0.627045822445535
# Epoch loss:  -8956.759354829788
# Epoch loss:  -8954.557181835175
# Epoch loss:  -8961.988515496254
# Epoch loss:  -8960.937938332558
# Epoch loss:  -8968.186096668243
# sum of reward per episode:  4891.022636045369
# sum of reward per episode:  4890.315259162905
# sum of reward per episode:  4899.112502569139
# sum of reward per episode:  4302.9734066184765
# sum of reward per episode:  4907.769830950838
# Epoch 80, Average score: 104.05036055499014
# Std score: 5.142781103002885
# Epoch loss:  -8968.123214483261
# Epoch loss:  -8972.030039787292
# Epoch loss:  -8974.803616046906
# Epoch loss:  -8978.145472049713
# Epoch loss:  -8975.42852962017
# sum of reward per episode:  4979.866147213248
# sum of reward per episode:  4982.300684622877
# sum of reward per episode:  4964.847528951029
# sum of reward per episode:  4968.899869725263
# sum of reward per episode:  4833.751291034116
# Epoch 85, Average score: 107.70329881896508
# Std score: 1.1946079879470475
# Epoch loss:  -8981.862224340439
# Epoch loss:  -8982.423825383186
# Epoch loss:  -8986.998519420624
# Epoch loss:  -8989.038717150688
# Epoch loss:  -8985.982656002045
# sum of reward per episode:  4874.227871051203
# sum of reward per episode:  4864.1658649038145
# sum of reward per episode:  4879.085031013483
# sum of reward per episode:  4860.710323097524
# sum of reward per episode:  4840.955745413831
# Epoch 90, Average score: 105.91479911257309
# Std score: 0.25250108933375454
# Epoch loss:  -8991.528696417809
# Epoch loss:  -8995.405007839203
# Epoch loss:  -8995.653566718102
# Epoch loss:  -8997.280054092407
# Epoch loss:  -9000.119662642479
# sum of reward per episode:  4924.787882091055
# sum of reward per episode:  4883.729986020356
# sum of reward per episode:  4906.069198265711
# sum of reward per episode:  4888.32713995283
# sum of reward per episode:  4871.850544407652
# Epoch 95, Average score: 106.59278242058588
# Std score: 0.3682144175220605
# Epoch loss:  -9005.584490537643
# Epoch loss:  -9001.926097989082
# Epoch loss:  -9004.088292241096
# Epoch loss:  -9009.47156059742
# Model saved to trained_mle_model_walker2d-medium-expert-v2.pth
#
# Mean of the last 10 Average Scores for walker2d-medium-expert-v2: 105.55387584702535
# Mean of the last 10 Std Scores for walker2d-medium-expert-v2: 2.8586827610492485
#
# Final Results Table:
# +------------------------------+-----------------------------+-------------------------+
# |           Dataset            | Mean Last 10 Average Scores | Mean Last 10 Std Scores |
# +------------------------------+-----------------------------+-------------------------+
# |    halfcheetah-medium-v2     |      41.69743183665007      |    3.0957079462168395   |
# | halfcheetah-medium-expert-v2 |      91.67745775980195      |    3.663157076259207    |
# |       hopper-medium-v2       |      43.92780653761171      |    3.380330455487654    |
# |   hopper-medium-expert-v2    |       56.255274092515       |    7.106855695353201    |
# |      walker2d-medium-v2      |       72.7443215220226      |    9.549854199781397    |
# |  walker2d-medium-expert-v2   |      105.55387584702535     |    2.8586827610492485   |
# +------------------------------+-----------------------------+-------------------------+
